# %% [markdown]
# # Search Text Flood
# Author: Mark Bauer

# %% [markdown]
# Goal: To search for the text pattern *flood* in every column in every dataset with more than 1M rows on NYC Open Data. Because of the size of these datasets, we'll utilize the Socrata API.

# %% [markdown]
# # Importing Libraries

# %%
# importing libraries
import pandas as pd
import numpy as np
from sodapy import Socrata
import requests
import time

# %% [markdown]
# Documention for installing watermark: https://github.com/rasbt/watermark.

# %%
# performed for reproducibility
# %reload_ext watermark
# %watermark -t -d -v -p pandas,sodapy
# Out:
# Python implementation: CPython
# Python version       : 3.11.0
# IPython version      : 8.6.0
#
# pandas: 1.5.1
# sodapy: 2.2.0

# %% [markdown]
# # Socrata API
# I used the Socrata API to retrieve metadata for datasets hosted on NYC Open Data. Documentation can be found here: https://dev.socrata.com/. Additionally, I used sodapy, the python client for the Socrata API, to query the metadata.
#
# We'll use this API to gather all the datasets on NYC Open Data.

# %% [markdown]
# ### Note:
# `WARNING:root:Requests made without an app_token will be subject to strict throttling limits.`
#
# Read more from the SODA documentation here: https://dev.socrata.com/docs/app-tokens.html

# %%
ls
# Out:
# analysis.ipynb                          search-text-flood.ipynb
# cover-photo.ipynb                       searchstring-flood.ipynb
# search-text-flood-large-datasets.ipynb

# %%
# retrieve export log from the other script, datasets less than 1M rows
datasets = pd.read_csv(
    "../logs/export-log.txt",
    on_bad_lines='skip',
    names=['timestamp', 'dataset', 'column'],
    low_memory=False
)

print(datasets.shape)
datasets.head()
# Out:
# (55047, 3)
#              timestamp               dataset                     column
# 0  2024-12-28 22:16:19  Processing mhyv-6iza                        NaN
# 1  2024-12-28 22:16:20  Processing mhyv-6iza          column Trust Name
# 2  2024-12-28 22:16:20  Processing mhyv-6iza    column Expenditure Name
# 3  2024-12-28 22:16:20  Processing mhyv-6iza              column Amount
# 4  2024-12-28 22:16:20  Processing mhyv-6iza  column Date of Incurrence

# %%
datasets = (
    datasets
    .loc[datasets['dataset'].fillna("").str.contains('too many rows')]
    .drop(columns=['column'])
    .reset_index(drop=True)
)

print(datasets.shape)
datasets.head()
# Out:
# (162, 2)
#              timestamp                                   dataset
# 0  2024-12-28 22:19:05  Skipping u9wf-3gbt due to too many rows.
# 1  2024-12-28 22:25:47  Skipping c23c-uwsm due to too many rows.
# 2  2024-12-28 22:34:17  Skipping 5zhs-2jue due to too many rows.
# 3  2024-12-28 23:00:59  Skipping 6a2s-2t65 due to too many rows.
# 4  2024-12-28 23:04:24  Skipping fvp3-gcb2 due to too many rows.

# %%
datasets['dataset_id'] = datasets['dataset'].str.split(" ").str[1]

datasets
# Out:
#                timestamp                                   dataset dataset_id
# 0    2024-12-28 22:19:05  Skipping u9wf-3gbt due to too many rows.  u9wf-3gbt
# 1    2024-12-28 22:25:47  Skipping c23c-uwsm due to too many rows.  c23c-uwsm
# 2    2024-12-28 22:34:17  Skipping 5zhs-2jue due to too many rows.  5zhs-2jue
# 3    2024-12-28 23:00:59  Skipping 6a2s-2t65 due to too many rows.  6a2s-2t65
# 4    2024-12-28 23:04:24  Skipping fvp3-gcb2 due to too many rows.  fvp3-gcb2
# ..                   ...                                       ...        ...
# 157  2024-12-29 08:26:16  Skipping ic3t-wcy2 due to too many rows.  ic3t-wcy2
# 158  2024-12-29 08:28:43  Skipping ipu4-2q9a due to too many rows.  ipu4-2q9a
# 159  2024-12-29 08:29:48  Skipping rhe8-mgbb due to too many rows.  rhe8-mgbb
# 160  2024-12-29 08:30:28  Skipping h9gi-nx95 due to too many rows.  h9gi-nx95
# 161  2024-12-29 08:33:58  Skipping erm2-nwe9 due to too many rows.  erm2-nwe9
#
# [162 rows x 3 columns]

# %%
# source domain for NYC Open Data on Socrata
socrata_domain = 'data.cityofnewyork.us'

# initialize Socrata object to fetch data
client = Socrata(
    domain=socrata_domain,
    app_token=None,
    timeout=10000
)

print(client)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# <sodapy.socrata.Socrata object at 0x1683eb150>

# %%
# Discovery API
url = 'https://api.us.socrata.com/api/catalog/v1?search_context=data.cityofnewyork.us&limit=50000'

# fetch the JSON data from the web
response = requests.get(url)

# parse the JSON response
data_dict = response.json() 

# preview keys    
data_dict.keys()
# Out:
# dict_keys(['results', 'resultSetSize', 'timings', 'warnings'])

# %%
# convert into df
df = pd.DataFrame.from_records(data_dict['results'])

# sanity check
print(df.shape)
df.head()
# Out:
# (3240, 8)
#                                             resource  \
# 0  {'name': 'For Hire Vehicles (FHV) - Active', '...
# 1  {'name': 'Civil Service List (Active)', 'id': ...
# 2  {'name': 'DOB Job Application Filings', 'id': ...
# 3  {'name': 'TLC New Driver Application Status', ...
# 4  {'name': 'For Hire Vehicles (FHV) - Active Dri...
#
#                                       classification  \
# 0  {'categories': [], 'tags': [], 'domain_categor...
# 1  {'categories': [], 'tags': [], 'domain_categor...
# 2  {'categories': [], 'tags': [], 'domain_categor...
# 3  {'categories': [], 'tags': [], 'domain_categor...
# 4  {'categories': [], 'tags': [], 'domain_categor...
#
#                               metadata  \
# 0  {'domain': 'data.cityofnewyork.us'}
# 1  {'domain': 'data.cityofnewyork.us'}
# 2  {'domain': 'data.cityofnewyork.us'}
# 3  {'domain': 'data.cityofnewyork.us'}
# 4  {'domain': 'data.cityofnewyork.us'}
#
#                                    permalink  \
# 0  https://data.cityofnewyork.us/d/8wbx-tsch
# 1  https://data.cityofnewyork.us/d/vx8i-nprf
# 2  https://data.cityofnewyork.us/d/ic3t-wcy2
# 3  https://data.cityofnewyork.us/d/dpec-ucu7
# 4  https://data.cityofnewyork.us/d/xjfq-wh2d
#
#                                                 link  \
# 0  https://data.cityofnewyork.us/Transportation/F...
# 1  https://data.cityofnewyork.us/City-Government/...
# 2  https://data.cityofnewyork.us/Housing-Developm...
# 3  https://data.cityofnewyork.us/Transportation/T...
# 4  https://data.cityofnewyork.us/Transportation/F...
#
#                                                owner  \
# 0  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 1  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 2  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 3  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 4  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
#
#                                              creator preview_image_url
# 0  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 1  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 2  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 3  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 4  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN

# %%
# convert resource key to a dataframe
df = pd.DataFrame.from_records(df['resource'])

# sanity check
print(df.shape)
df.head()
# Out:
# (3240, 27)
#                                        name         id resource_name  \
# 0          For Hire Vehicles (FHV) - Active  8wbx-tsch          None
# 1               Civil Service List (Active)  vx8i-nprf          None
# 2               DOB Job Application Filings  ic3t-wcy2          None
# 3         TLC New Driver Application Status  dpec-ucu7          None
# 4  For Hire Vehicles (FHV) - Active Drivers  xjfq-wh2d          None
#
#   parent_fxf                                        description  \
# 0         []  <b>PLEASE NOTE:</b> This dataset, which includ...
# 1         []  A Civil Service List consists of all candidate...
# 2         []  This dataset contains all job applications sub...
# 3         []  THIS DATASET IS UPDATED SEVERAL TIMES PER DAY....
# 4         []  <b>PLEASE NOTE:</b> This dataset, which includ...
#
#                                          attribution attribution_link  \
# 0                Taxi and Limousine Commission (TLC)             None
# 1  Department of Citywide Administrative Services...             None
# 2                      Department of Buildings (DOB)             None
# 3                Taxi and Limousine Commission (TLC)             None
# 4                Taxi and Limousine Commission (TLC)             None
#
#   contact_email     type                 updatedAt  ...  \
# 0          None  dataset  2024-12-29T20:05:32.000Z  ...
# 1          None  dataset  2024-12-27T14:09:28.000Z  ...
# 2          None  dataset  2024-12-29T21:06:44.000Z  ...
# 3          None  dataset  2024-12-29T23:06:31.000Z  ...
# 4          None  dataset  2024-12-29T20:07:08.000Z  ...
#
#                                  columns_description  \
# 0  [Last Time Updated, Certification Date, Base N...
# 1  [A candidate’s last name as it appears on thei...
# 2  [Proposed Dwelling Units, Document Number, Num...
# 3  [This is the number linked to your application...
# 4  [Driver Name\n\n, Last Time Updated, Type of L...
#
#                                       columns_format download_count  \
# 0  [{'displayStyle': 'plain', 'align': 'left'}, {...         535601
# 1  [{'displayStyle': 'plain', 'align': 'left'}, {...          68870
# 2  [{'align': 'right'}, {'align': 'right'}, {'ali...          59754
# 3  [{'precisionStyle': 'standard', 'noCommas': 't...          39667
# 4  [{'displayStyle': 'plain', 'align': 'left'}, {...         421843
#
#   provenance lens_view_type lens_display_type locked blob_mime_type  \
# 0   official        tabular             table  False           None
# 1   official        tabular             table  False           None
# 2   official        tabular             table  False           None
# 3   official        tabular             table  False           None
# 4   official        tabular             table  False           None
#
#   hide_from_data_json          publication_date
# 0               False  2021-04-05T13:20:47.000Z
# 1               False  2024-01-12T16:15:05.000Z
# 2               False  2020-06-22T18:23:35.000Z
# 3               False  2019-12-17T18:44:57.000Z
# 4               False  2024-01-11T19:58:17.000Z
#
# [5 rows x 27 columns]

# %%
dataset_ids = datasets['dataset_id'].to_list()

df = df.loc[df['id'].isin(dataset_ids)].reset_index(drop=True)

# sanity check
print(df.shape)
df.head()
# Out:
# (162, 27)
#                                         name         id resource_name  \
# 0                DOB Job Application Filings  ic3t-wcy2          None
# 1  311 Service Requests from 2010 to Present  erm2-nwe9          None
# 2           Civil Service List Certification  a9md-ynri          None
# 3        Citywide Payroll Data (Fiscal Year)  k397-673e          None
# 4         Motor Vehicle Collisions - Crashes  h9gi-nx95          None
#
#   parent_fxf                                        description  \
# 0         []  This dataset contains all job applications sub...
# 1         []  <b>NOTE:</b> The 311 dataset is currently show...
# 2         []  A List Certification includes the names of eli...
# 3         []  Data is collected because of public interest i...
# 4         []  The Motor Vehicle Collisions crash table conta...
#
#                                          attribution attribution_link  \
# 0                      Department of Buildings (DOB)             None
# 1                                                311             None
# 2  Department of Citywide Administrative Services...             None
# 3             Office of Payroll Administration (OPA)             None
# 4                           Police Department (NYPD)             None
#
#   contact_email     type                 updatedAt  ...  \
# 0          None  dataset  2024-12-29T21:06:44.000Z  ...
# 1          None  dataset  2024-12-29T02:33:06.000Z  ...
# 2          None  dataset  2024-12-27T14:12:33.000Z  ...
# 3          None  dataset  2024-10-30T15:00:01.000Z  ...
# 4          None  dataset  2024-12-27T23:54:06.000Z  ...
#
#                                  columns_description  \
# 0  [Proposed Dwelling Units, Document Number, Num...
# 1  [, Indicates how the SR was submitted to 311. ...
# 2  [The name of an appointing Agency.\n, An eligi...
# 3  [Payroll Number, Number of regular hours emplo...
# 4  [, Street address if known, Factors contributi...
#
#                                       columns_format download_count  \
# 0  [{'align': 'right'}, {'align': 'right'}, {'ali...          59754
# 1  [{}, {'displayStyle': 'plain', 'align': 'left'...         446207
# 2  [{'displayStyle': 'plain', 'align': 'left'}, {...          22427
# 3  [{}, {}, {'precisionStyle': 'currency', 'curre...          36880
# 4  [{}, {'align': 'left'}, {'align': 'left'}, {'a...         207788
#
#   provenance lens_view_type lens_display_type locked blob_mime_type  \
# 0   official        tabular             table  False           None
# 1   official        tabular             table  False           None
# 2   official        tabular             table  False           None
# 3   official        tabular             table  False           None
# 4   official        tabular             table  False           None
#
#   hide_from_data_json          publication_date
# 0               False  2020-06-22T18:23:35.000Z
# 1               False  2023-12-01T06:51:46.000Z
# 2               False  2021-04-22T15:38:30.000Z
# 3               False  2023-11-28T17:52:17.000Z
# 4               False  2021-04-19T14:42:57.000Z
#
# [5 rows x 27 columns]

# %%
# preview columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 162 non-null    object
#  1   id                   162 non-null    object
#  2   resource_name        0 non-null      object
#  3   parent_fxf           162 non-null    object
#  4   description          162 non-null    object
#  5   attribution          156 non-null    object
#  6   attribution_link     43 non-null     object
#  7   contact_email        0 non-null      object
#  8   type                 162 non-null    object
#  9   updatedAt            162 non-null    object
#  10  createdAt            162 non-null    object
#  11  metadata_updated_at  162 non-null    object
#  12  data_updated_at      162 non-null    object
#  13  page_views           162 non-null    object
#  14  columns_name         162 non-null    object
#  15  columns_field_name   162 non-null    object
#  16  columns_datatype     162 non-null    object
#  17  columns_description  162 non-null    object
#  18  columns_format       162 non-null    object
#  19  download_count       162 non-null    int64
#  20  provenance           162 non-null    object
#  21  lens_view_type       162 non-null    object
#  22  lens_display_type    162 non-null    object
#  23  locked               162 non-null    bool
#  24  blob_mime_type       0 non-null      object
#  25  hide_from_data_json  162 non-null    bool
#  26  publication_date     161 non-null    object
# dtypes: bool(2), int64(1), object(24)
# memory usage: 32.1+ KB

# %%
# review dataset types, we only want datasets
df['type'].value_counts()
# Out:
# dataset    162
# Name: type, dtype: int64

# %%
# we only want datasets
df = (
    df
    .loc[df['type'] == 'dataset']
    .reset_index(drop=True)
)

# sanity check
print(df.shape)
df.head()
# Out:
# (162, 27)
#                                         name         id resource_name  \
# 0                DOB Job Application Filings  ic3t-wcy2          None
# 1  311 Service Requests from 2010 to Present  erm2-nwe9          None
# 2           Civil Service List Certification  a9md-ynri          None
# 3        Citywide Payroll Data (Fiscal Year)  k397-673e          None
# 4         Motor Vehicle Collisions - Crashes  h9gi-nx95          None
#
#   parent_fxf                                        description  \
# 0         []  This dataset contains all job applications sub...
# 1         []  <b>NOTE:</b> The 311 dataset is currently show...
# 2         []  A List Certification includes the names of eli...
# 3         []  Data is collected because of public interest i...
# 4         []  The Motor Vehicle Collisions crash table conta...
#
#                                          attribution attribution_link  \
# 0                      Department of Buildings (DOB)             None
# 1                                                311             None
# 2  Department of Citywide Administrative Services...             None
# 3             Office of Payroll Administration (OPA)             None
# 4                           Police Department (NYPD)             None
#
#   contact_email     type                 updatedAt  ...  \
# 0          None  dataset  2024-12-29T21:06:44.000Z  ...
# 1          None  dataset  2024-12-29T02:33:06.000Z  ...
# 2          None  dataset  2024-12-27T14:12:33.000Z  ...
# 3          None  dataset  2024-10-30T15:00:01.000Z  ...
# 4          None  dataset  2024-12-27T23:54:06.000Z  ...
#
#                                  columns_description  \
# 0  [Proposed Dwelling Units, Document Number, Num...
# 1  [, Indicates how the SR was submitted to 311. ...
# 2  [The name of an appointing Agency.\n, An eligi...
# 3  [Payroll Number, Number of regular hours emplo...
# 4  [, Street address if known, Factors contributi...
#
#                                       columns_format download_count  \
# 0  [{'align': 'right'}, {'align': 'right'}, {'ali...          59754
# 1  [{}, {'displayStyle': 'plain', 'align': 'left'...         446207
# 2  [{'displayStyle': 'plain', 'align': 'left'}, {...          22427
# 3  [{}, {}, {'precisionStyle': 'currency', 'curre...          36880
# 4  [{}, {'align': 'left'}, {'align': 'left'}, {'a...         207788
#
#   provenance lens_view_type lens_display_type locked blob_mime_type  \
# 0   official        tabular             table  False           None
# 1   official        tabular             table  False           None
# 2   official        tabular             table  False           None
# 3   official        tabular             table  False           None
# 4   official        tabular             table  False           None
#
#   hide_from_data_json          publication_date
# 0               False  2020-06-22T18:23:35.000Z
# 1               False  2023-12-01T06:51:46.000Z
# 2               False  2021-04-22T15:38:30.000Z
# 3               False  2023-11-28T17:52:17.000Z
# 4               False  2021-04-19T14:42:57.000Z
#
# [5 rows x 27 columns]

# %%
# sanity check view type
df['lens_view_type'].value_counts()
# Out:
# tabular    162
# Name: lens_view_type, dtype: int64

# %%
# sort df by download count ascending order
df = (
    df
    .sort_values(by='download_count')
    .reset_index(drop=True)
)

# sanity check
print(df.shape)
df.head()
# Out:
# (162, 27)
#                             name         id resource_name parent_fxf  \
# 0  Building Footprints (P Layer)  u9wf-3gbt          None         []
# 1       SweepNYC Street Cleaning  c23c-uwsm          None         []
# 2            Building Footprints  5zhs-2jue          None         []
# 3     2012 Yellow Taxi Trip Data  kerk-3eby          None         []
# 4      Local Law 84 Monthly Data  fvp3-gcb2          None         []
#
#                                          description  \
# 0  Shapefile of footprint outlines of buildings i...
# 1  This dataset contains NYC Street Centerline (C...
# 2  Shapefile of footprint outlines of buildings i...
# 3  These records are generated from the trip reco...
# 4  Monthly whole building electricity and natural...
#
#                                  attribution  \
# 0  Office of Technology and Innovation (OTI)
# 1            Department of Sanitation (DSNY)
# 2  Office of Technology and Innovation (OTI)
# 3        Taxi and Limousine Commission (TLC)
# 4              Department of Buildings (DOB)
#
#                                     attribution_link contact_email     type  \
# 0                                               None          None  dataset
# 1                                               None          None  dataset
# 2                                               None          None  dataset
# 3  https://www.nyc.gov/site/tlc/about/tlc-trip-re...          None  dataset
# 4                                               None          None  dataset
#
#                   updatedAt  ...  \
# 0  2024-12-24T18:15:01.000Z  ...
# 1  2024-12-29T15:50:54.000Z  ...
# 2  2024-12-24T18:24:48.000Z  ...
# 3  2023-12-14T20:44:28.000Z  ...
# 4  2024-10-01T19:34:42.000Z  ...
#
#                                  columns_description  \
# 0  [This column was automatically created in orde...
# 1  [Date and time when street segment was last as...
# 2  [Geometry column used for mapping, Type of Bui...
# 3  [Miscellaneous extras and surcharges. Currentl...
# 4  [Energy Use by Type is a summary of the annual...
#
#                                       columns_format download_count  \
# 0  [{}, {}, {'noCommas': 'true'}, {}, {}, {}, {},...             42
# 1                                       [{}, {}, {}]             86
# 2  [{}, {'noCommas': 'true'}, {}, {'noCommas': 't...            121
# 3  [{'precisionStyle': 'standard', 'noCommas': 'f...            260
# 4  [{}, {'noCommas': 'true'}, {}, {}, {}, {}, {},...            261
#
#   provenance lens_view_type lens_display_type locked blob_mime_type  \
# 0   official        tabular             table  False           None
# 1   official        tabular             table  False           None
# 2   official        tabular             table  False           None
# 3   official        tabular             table  False           None
# 4   official        tabular             table  False           None
#
#   hide_from_data_json          publication_date
# 0               False  2024-11-19T16:45:45.000Z
# 1               False  2024-09-27T19:30:02.000Z
# 2               False  2024-11-13T16:16:55.000Z
# 3               False  2015-12-08T21:22:21.000Z
# 4               False  2024-10-01T15:22:10.000Z
#
# [5 rows x 27 columns]

# %%
field_names_df = df.loc[:, ['id', 'columns_field_name']].explode('columns_field_name')
field_types_df = df.loc[:, ['id', 'columns_datatype']].explode('columns_datatype')

df = (
    pd
    .concat([field_names_df, field_types_df.drop(columns=['id'])], axis=1)
    .reset_index(drop=True)
)

# sanity check
print(df.shape)
df.head()
# Out:
# (4292, 3)
#           id           columns_field_name columns_datatype
# 0  u9wf-3gbt  :@computed_region_f5dn_yrer           Number
# 1  u9wf-3gbt                     the_geom            Point
# 2  u9wf-3gbt                    feat_code           Number
# 3  u9wf-3gbt                   groundelev           Number
# 4  u9wf-3gbt                     base_bbl             Text

# %%
df = (
    df
    .loc[df['columns_datatype'] == 'Text']
    .reset_index(drop=True)
)

# sanity check
print(df.shape)
df.head()
# Out:
# (2324, 3)
#           id columns_field_name columns_datatype
# 0  u9wf-3gbt           base_bbl             Text
# 1  u9wf-3gbt         geomsource             Text
# 2  u9wf-3gbt         mpluto_bbl             Text
# 3  u9wf-3gbt               name             Text
# 4  u9wf-3gbt         lststatype             Text

# %%
# number of dataset
df['id'].nunique()
# Out:
# 161

# %%
# save as a CSV file
df.to_csv('../data/dataset-ids-columns.csv', index=False)

# %%
# sanity check
# %ls ../data/
# Out:
# columns-large-datasets.csv  dataset-ids.csv
# columns.csv                 datasets.csv
# dataset-ids-columns.csv
