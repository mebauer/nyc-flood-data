# %% [markdown]
# # Text Flood
# Author: Mark Bauer

# %% [markdown]
# Goal: Analyze character word *flood* from every dataset on NYC Open Data.

# %% [markdown]
# # Importing Libraries

# %%
# importing libraries
import pandas as pd
import numpy as np
from sodapy import Socrata
import requests
import time
import os
import glob

# %% [markdown]
# Documention for installing watermark: https://github.com/rasbt/watermark.

# %%
# performed for reproducibility
# %reload_ext watermark
# %watermark -t -d -v -p pandas,sodapy
# Out:
# Python implementation: CPython
# Python version       : 3.11.0
# IPython version      : 8.6.0
#
# pandas: 1.5.1
# sodapy: 2.2.0

# %% [markdown]
# # Socrata API
# I used the Socrata API to retrieve metadata for datasets hosted on NYC Open Data. Documentation can be found here: https://dev.socrata.com/. Additionally, I used sodapy, the python client for the Socrata API, to query the metadata.
#
# We'll use this API to gather all the datasets on NYC Open Data.

# %% [markdown]
# ### Note:
# `WARNING:root:Requests made without an app_token will be subject to strict throttling limits.`
#
# Read more from the SODA documentation here: https://dev.socrata.com/docs/app-tokens.html

# %%
# source domain for NYC Open Data on Socrata
socrata_domain = 'data.cityofnewyork.us'

# initialize Socrata object to fetch data
client = Socrata(
    domain=socrata_domain,
    app_token=None,
    timeout=1000
)

print(client)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# <sodapy.socrata.Socrata object at 0x1067cb590>

# %%
# Discovery API
url = 'https://api.us.socrata.com/api/catalog/v1?search_context=data.cityofnewyork.us&limit=50000'

# fetch the JSON data from the web
response = requests.get(url)

# parse the JSON response
data_dict = response.json() 

# preview keys    
data_dict.keys()
# Out:
# dict_keys(['results', 'resultSetSize', 'timings', 'warnings'])

# %%
# convert into df
metadata_df = pd.DataFrame.from_records(data_dict['results'])

# sanity check
print(metadata_df.shape)
metadata_df.head()
# Out:
# (3245, 8)
#                                             resource  \
# 0  {'name': 'For Hire Vehicles (FHV) - Active', '...
# 1  {'name': 'Civil Service List (Active)', 'id': ...
# 2  {'name': 'DOB Job Application Filings', 'id': ...
# 3  {'name': 'TLC New Driver Application Status', ...
# 4  {'name': 'For Hire Vehicles (FHV) - Active Dri...
#
#                                       classification  \
# 0  {'categories': [], 'tags': [], 'domain_categor...
# 1  {'categories': [], 'tags': [], 'domain_categor...
# 2  {'categories': [], 'tags': [], 'domain_categor...
# 3  {'categories': [], 'tags': [], 'domain_categor...
# 4  {'categories': [], 'tags': [], 'domain_categor...
#
#                               metadata  \
# 0  {'domain': 'data.cityofnewyork.us'}
# 1  {'domain': 'data.cityofnewyork.us'}
# 2  {'domain': 'data.cityofnewyork.us'}
# 3  {'domain': 'data.cityofnewyork.us'}
# 4  {'domain': 'data.cityofnewyork.us'}
#
#                                    permalink  \
# 0  https://data.cityofnewyork.us/d/8wbx-tsch
# 1  https://data.cityofnewyork.us/d/vx8i-nprf
# 2  https://data.cityofnewyork.us/d/ic3t-wcy2
# 3  https://data.cityofnewyork.us/d/dpec-ucu7
# 4  https://data.cityofnewyork.us/d/xjfq-wh2d
#
#                                                 link  \
# 0  https://data.cityofnewyork.us/Transportation/F...
# 1  https://data.cityofnewyork.us/City-Government/...
# 2  https://data.cityofnewyork.us/Housing-Developm...
# 3  https://data.cityofnewyork.us/Transportation/T...
# 4  https://data.cityofnewyork.us/Transportation/F...
#
#                                                owner  \
# 0  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 1  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 2  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 3  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 4  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
#
#                                              creator preview_image_url
# 0  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 1  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 2  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 3  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 4  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN

# %%
# convert resource key to a dataframe
metadata_df = pd.DataFrame.from_records(metadata_df['resource'])

# sanity check
print(metadata_df.shape)
metadata_df.head()
# Out:
# (3245, 27)
#                                        name         id resource_name  \
# 0          For Hire Vehicles (FHV) - Active  8wbx-tsch          None
# 1               Civil Service List (Active)  vx8i-nprf          None
# 2               DOB Job Application Filings  ic3t-wcy2          None
# 3         TLC New Driver Application Status  dpec-ucu7          None
# 4  For Hire Vehicles (FHV) - Active Drivers  xjfq-wh2d          None
#
#   parent_fxf                                        description  \
# 0         []  <b>PLEASE NOTE:</b> This dataset, which includ...
# 1         []  A Civil Service List consists of all candidate...
# 2         []  This dataset contains all job applications sub...
# 3         []  THIS DATASET IS UPDATED SEVERAL TIMES PER DAY....
# 4         []  <b>PLEASE NOTE:</b> This dataset, which includ...
#
#                                          attribution attribution_link  \
# 0                Taxi and Limousine Commission (TLC)             None
# 1  Department of Citywide Administrative Services...             None
# 2                      Department of Buildings (DOB)             None
# 3                Taxi and Limousine Commission (TLC)             None
# 4                Taxi and Limousine Commission (TLC)             None
#
#   contact_email     type                 updatedAt  ...  \
# 0          None  dataset  2024-12-31T19:59:30.000Z  ...
# 1          None  dataset  2025-01-01T14:16:19.000Z  ...
# 2          None  dataset  2024-12-31T21:13:45.000Z  ...
# 3          None  dataset  2025-01-01T11:06:04.000Z  ...
# 4          None  dataset  2024-12-31T20:00:56.000Z  ...
#
#                                  columns_description  \
# 0  [DMV License Plate Number, Permit License Numb...
# 1  [Represents the certification order for a list...
# 2  [Job is Professionally Certified by Licensed P...
# 3  [The date you submitted your application., A N...
# 4  [Last Time Updated, Driver Name\n\n, Expiratio...
#
#                                       columns_format download_count  \
# 0  [{'displayStyle': 'plain', 'align': 'left'}, {...         536011
# 1  [{'displayStyle': 'plain', 'align': 'left'}, {...          68956
# 2  [{'align': 'right'}, {'align': 'right'}, {'ali...          59793
# 3  [{'view': 'date', 'align': 'left'}, {'displayS...          39678
# 4  [{'displayStyle': 'plain', 'align': 'left'}, {...         422194
#
#   provenance lens_view_type lens_display_type locked blob_mime_type  \
# 0   official        tabular             table  False           None
# 1   official        tabular             table  False           None
# 2   official        tabular             table  False           None
# 3   official        tabular             table  False           None
# 4   official        tabular             table  False           None
#
#   hide_from_data_json          publication_date
# 0               False  2021-04-05T13:20:47.000Z
# 1               False  2024-01-12T16:15:05.000Z
# 2               False  2020-06-22T18:23:35.000Z
# 3               False  2019-12-17T18:44:57.000Z
# 4               False  2024-01-11T19:58:17.000Z
#
# [5 rows x 27 columns]

# %%
cols = [
    'name', 'id', 'description',
    'attribution', 'createdAt', 'publication_date', 'updatedAt',
    'metadata_updated_at', 'data_updated_at', 'download_count', 'page_views',
    'columns_name', 'columns_field_name', 'columns_datatype',
    'columns_description', 'columns_format'
]
       
metadata_df = metadata_df.loc[:, cols]

metadata_df.head()
# Out:
#                                        name         id  \
# 0          For Hire Vehicles (FHV) - Active  8wbx-tsch
# 1               Civil Service List (Active)  vx8i-nprf
# 2               DOB Job Application Filings  ic3t-wcy2
# 3         TLC New Driver Application Status  dpec-ucu7
# 4  For Hire Vehicles (FHV) - Active Drivers  xjfq-wh2d
#
#                                          description  \
# 0  <b>PLEASE NOTE:</b> This dataset, which includ...
# 1  A Civil Service List consists of all candidate...
# 2  This dataset contains all job applications sub...
# 3  THIS DATASET IS UPDATED SEVERAL TIMES PER DAY....
# 4  <b>PLEASE NOTE:</b> This dataset, which includ...
#
#                                          attribution  \
# 0                Taxi and Limousine Commission (TLC)
# 1  Department of Citywide Administrative Services...
# 2                      Department of Buildings (DOB)
# 3                Taxi and Limousine Commission (TLC)
# 4                Taxi and Limousine Commission (TLC)
#
#                   createdAt          publication_date  \
# 0  2015-07-16T17:33:32.000Z  2021-04-05T13:20:47.000Z
# 1  2016-06-14T21:12:15.000Z  2024-01-12T16:15:05.000Z
# 2  2013-04-18T15:18:56.000Z  2020-06-22T18:23:35.000Z
# 3  2016-05-17T18:43:43.000Z  2019-12-17T18:44:57.000Z
# 4  2015-07-16T17:24:02.000Z  2024-01-11T19:58:17.000Z
#
#                   updatedAt       metadata_updated_at  \
# 0  2024-12-31T19:59:30.000Z  2022-09-06T21:05:32.000Z
# 1  2025-01-01T14:16:19.000Z  2024-05-14T14:26:52.000Z
# 2  2024-12-31T21:13:45.000Z  2020-06-23T02:08:44.000Z
# 3  2025-01-01T11:06:04.000Z  2022-05-09T22:28:03.000Z
# 4  2024-12-31T20:00:56.000Z  2024-01-11T19:58:17.000Z
#
#             data_updated_at  download_count  \
# 0  2024-12-31T19:59:30.000Z          536011
# 1  2025-01-01T14:16:19.000Z           68956
# 2  2024-12-31T21:13:45.000Z           59793
# 3  2025-01-01T11:06:04.000Z           39678
# 4  2024-12-31T20:00:56.000Z          422194
#
#                                           page_views  \
# 0  {'page_views_last_week': 5937, 'page_views_las...
# 1  {'page_views_last_week': 5129, 'page_views_las...
# 2  {'page_views_last_week': 283, 'page_views_last...
# 3  {'page_views_last_week': 97, 'page_views_last_...
# 4  {'page_views_last_week': 2187, 'page_views_las...
#
#                                         columns_name  \
# 0  [DMV License Plate Number, Permit License Numb...
# 1  [Group No, First Name, List Agency Desc, List ...
# 2  [Professional Cert, BUILDING_CLASS, Horizontal...
# 3  [App Date, Defensive Driving, Driver Exam, App...
# 4  [Last Time Updated, Name, Expiration Date, Las...
#
#                                   columns_field_name  \
# 0  [dmv_license_plate_number, permit_license_numb...
# 1  [group_no, first_name, list_agency_desc, list_...
# 2  [professional_cert, building_class, horizontal...
# 3  [app_date, defensive_driving, driver_exam, app...
# 4  [last_time_updated, name, expiration_date, las...
#
#                                     columns_datatype  \
# 0  [Text, Text, Calendar date, Calendar date, Tex...
# 1  [Text, Text, Text, Text, Text, Text, Number, T...
# 2  [Text, Text, Text, Text, Text, Text, Text, Tex...
# 3  [Calendar date, Text, Text, Number, Text, Cale...
# 4  [Text, Text, Calendar date, Calendar date, Num...
#
#                                  columns_description  \
# 0  [DMV License Plate Number, Permit License Numb...
# 1  [Represents the certification order for a list...
# 2  [Job is Professionally Certified by Licensed P...
# 3  [The date you submitted your application., A N...
# 4  [Last Time Updated, Driver Name\n\n, Expiratio...
#
#                                       columns_format
# 0  [{'displayStyle': 'plain', 'align': 'left'}, {...
# 1  [{'displayStyle': 'plain', 'align': 'left'}, {...
# 2  [{'align': 'right'}, {'align': 'right'}, {'ali...
# 3  [{'view': 'date', 'align': 'left'}, {'displayS...
# 4  [{'displayStyle': 'plain', 'align': 'left'}, {...

# %%
# preview columns
metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3245 entries, 0 to 3244
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 3245 non-null   object
#  1   id                   3245 non-null   object
#  2   description          3245 non-null   object
#  3   attribution          3174 non-null   object
#  4   createdAt            3245 non-null   object
#  5   publication_date     3220 non-null   object
#  6   updatedAt            3245 non-null   object
#  7   metadata_updated_at  3245 non-null   object
#  8   data_updated_at      3068 non-null   object
#  9   download_count       3245 non-null   int64
#  10  page_views           3245 non-null   object
#  11  columns_name         3245 non-null   object
#  12  columns_field_name   3245 non-null   object
#  13  columns_datatype     3245 non-null   object
#  14  columns_description  3245 non-null   object
#  15  columns_format       3245 non-null   object
# dtypes: int64(1), object(15)
# memory usage: 405.8+ KB

# %% [markdown]
# # Read in results of our character match *flood*

# %%
path = "../results"

all_files = glob.glob(os.path.join(path, "*.csv"))
df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

print(df.shape)
df.head(10)
# Out:
# (19042, 5)
#             value  count            timestamp     column         id
# 0           Flood    525  2024-12-29 19:14:56  last_name  5gq7-rgmv
# 1      Flooderman      1  2024-12-29 19:14:56  last_name  5gq7-rgmv
# 2          Floods      1  2024-12-29 19:14:56  last_name  5gq7-rgmv
# 3  FLOOD,NICOLE,R     18  2024-12-29 19:20:49       name  c4dx-tk4d
# 4           Flood    719  2024-12-29 19:25:49  last_name  j62e-7maa
# 5          Floods      3  2024-12-29 19:25:49  last_name  j62e-7maa
# 6       Floodberg      1  2024-12-29 19:25:49  last_name  j62e-7maa
# 7       Floodirst      1  2024-12-29 19:25:49  last_name  j62e-7maa
# 8     Floodstrand      1  2024-12-29 19:25:49  last_name  j62e-7maa
# 9          Floody      1  2024-12-29 19:25:49  last_name  j62e-7maa

# %%
df = df.merge(
    metadata_df,
    on='id',
    how='left'
)

print(df.shape)
df.head()
# Out:
# (19042, 20)
#             value  count            timestamp     column         id  \
# 0           Flood    525  2024-12-29 19:14:56  last_name  5gq7-rgmv
# 1      Flooderman      1  2024-12-29 19:14:56  last_name  5gq7-rgmv
# 2          Floods      1  2024-12-29 19:14:56  last_name  5gq7-rgmv
# 3  FLOOD,NICOLE,R     18  2024-12-29 19:20:49       name  c4dx-tk4d
# 4           Flood    719  2024-12-29 19:25:49  last_name  j62e-7maa
#
#                                                 name  \
# 0  NYC Historical Vital Records: Index to Digitiz...
# 1  NYC Historical Vital Records: Index to Digitiz...
# 2  NYC Historical Vital Records: Index to Digitiz...
# 3  Historical Medallion Drivers – Passenger Assis...
# 4  NYC Historical Vital Records: Index to Digitiz...
#
#                                          description  \
# 0  The dataset is an index to digitized historica...
# 1  The dataset is an index to digitized historica...
# 2  The dataset is an index to digitized historica...
# 3  This list contains information on the status o...
# 4  The dataset is an index to digitized historica...
#
#                                          attribution  \
# 0  Department of Records and Information Services...
# 1  Department of Records and Information Services...
# 2  Department of Records and Information Services...
# 3                Taxi and Limousine Commission (TLC)
# 4  Department of Records and Information Services...
#
#                   createdAt          publication_date  \
# 0  2022-05-17T19:35:24.000Z  2023-07-19T15:32:38.000Z
# 1  2022-05-17T19:35:24.000Z  2023-07-19T15:32:38.000Z
# 2  2022-05-17T19:35:24.000Z  2023-07-19T15:32:38.000Z
# 3  2018-01-25T17:39:53.000Z  2018-01-29T22:12:30.000Z
# 4  2022-05-17T18:47:23.000Z  2023-07-19T15:29:27.000Z
#
#                   updatedAt       metadata_updated_at  \
# 0  2024-10-11T20:08:05.000Z  2024-10-11T20:06:00.000Z
# 1  2024-10-11T20:08:05.000Z  2024-10-11T20:06:00.000Z
# 2  2024-10-11T20:08:05.000Z  2024-10-11T20:06:00.000Z
# 3  2022-05-09T22:28:13.000Z  2022-05-09T22:28:13.000Z
# 4  2024-10-11T20:13:42.000Z  2024-10-11T20:08:22.000Z
#
#             data_updated_at  download_count  \
# 0  2024-10-11T20:08:05.000Z             463
# 1  2024-10-11T20:08:05.000Z             463
# 2  2024-10-11T20:08:05.000Z             463
# 3  2018-01-29T21:58:57.000Z             575
# 4  2024-10-11T20:13:42.000Z             633
#
#                                           page_views  \
# 0  {'page_views_last_week': 54, 'page_views_last_...
# 1  {'page_views_last_week': 54, 'page_views_last_...
# 2  {'page_views_last_week': 54, 'page_views_last_...
# 3  {'page_views_last_week': 3, 'page_views_last_m...
# 4  {'page_views_last_week': 45, 'page_views_last_...
#
#                                         columns_name  \
# 0  [Last Name, Certificate Month, First Name, Cer...
# 1  [Last Name, Certificate Month, First Name, Cer...
# 2  [Last Name, Certificate Month, First Name, Cer...
# 3  [License Number, Completed Both Training, Type...
# 4  [County, First Name, Soundex, Last Name, Certi...
#
#                                   columns_field_name  \
# 0  [last_name, month, first_name, year, soundex, ...
# 1  [last_name, month, first_name, year, soundex, ...
# 2  [last_name, month, first_name, year, soundex, ...
# 3  [license_number, completed_both, type, last_ti...
# 4  [county, first_name, soundex, last_name, year,...
#
#                                     columns_datatype  \
# 0   [Text, Text, Text, Text, Text, Text, Text, Text]
# 1   [Text, Text, Text, Text, Text, Text, Text, Text]
# 2   [Text, Text, Text, Text, Text, Text, Text, Text]
# 3  [Number, Text, Text, Text, Text, Calendar date...
# 4   [Text, Text, Text, Text, Text, Text, Text, Text]
#
#                                  columns_description  \
# 0  [Last name on the  certificate, Month of Birth...
# 1  [Last name on the  certificate, Month of Birth...
# 2  [Last name on the  certificate, Month of Birth...
# 3                                     [, , , , , , ]
# 4  [Borough in which the certificate was issued. ...
#
#                                       columns_format
# 0                   [{}, {}, {}, {}, {}, {}, {}, {}]
# 1                   [{}, {}, {}, {}, {}, {}, {}, {}]
# 2                   [{}, {}, {}, {}, {}, {}, {}, {}]
# 3  [{'precisionStyle': 'standard', 'noCommas': 't...
# 4                   [{}, {}, {}, {}, {}, {}, {}, {}]

# %%
# save results of full file
df.to_csv('../results/results-total.csv', index=False)

# %%
# count of values by agency
(df
 .groupby(by='attribution')['count']
 .sum()
 .sort_values(ascending=False)
 .head(60)
 .reset_index()
)
# Out:
#                                           attribution   count
# 0                                                 311  357706
# 1                  Department of Transportation (DOT)  233939
# 2   Department of Housing Preservation & Developme...   37243
# 3            Department of Parks and Recreation (DPR)   15582
# 4                       Department of Buildings (DOB)    9263
# 5                   Department of City Planning (DCP)    6006
# 6                    NYC Emergency Management (NYCEM)    4609
# 7                    NYC Department of Transportation    3220
# 8       New York City Office of Management and Budget    2542
# 9        Department of Environmental Protection (DEP)    2532
# 10  Department of Records and Information Services...    2531
# 11         Mayor's Office of Contract Services (MOCS)    2230
# 12  Department of Citywide Administrative Services...    1877
# 13  Office of Administrative Trials and Hearings (...    1601
# 14                      Business Integrity Commission    1542
# 15      Mayor’s Office of Management and Budget (OMB)    1293
# 16                School Construction Authority (SCA)    1281
# 17                       New York City Council (NYCC)    1111
# 18                Taxi and Limousine Commission (TLC)    1080
# 19                        Department of Finance (DOF)    1076
# 20                              Department of Finance     707
# 21             Office of Payroll Administration (OPA)     562
# 22        Mayor’s Office of Management & Budget (OMB)     492
# 23  Department of Housing Preservation and Develop...     446
# 24                 Mayor's Office of Operations (OPS)     429
# 25                                          NYC Parks     376
# 26          Office of Technology and Innovation (OTI)     372
# 27            Fire Department of New York City (FDNY)     285
# 28  Department of Consumer and Worker Protection (...     277
# 29  Mayor’s Office of Environmental Coordination (...     189
# 30  Mayor's Office of Climate and Environmental Ju...     185
# 31            NYC School Construction Authority (SCA)     133
# 32                     Public Design Commission (PDC)     125
# 33              Office of Management and Budget (OMB)     121
# 34            Mayor's Office for Economic Opportunity     103
# 35                          Office of the Comptroller      99
# 36                               Law Department (LAW)      95
# 37                       Campaign Finance Board (CFB)      75
# 38        Department of Small Business Services (SBS)      53
# 39             Civilian Complaint Review Board (CCRB)      31
# 40                     Office of the City Clerk (OCC)      26
# 41        Department of Design and Construction (DDC)      23
# 42                     Board of Standards and Appeals      19
# 43            Landmarks Preservation Commission (LPC)      18
# 44                                City Council (NYCC)      13
# 45  Mayor's Office of Ethnic and Community Media (...      11
# 46      Mayor's Office of Management and Budget (OMB)      11
# 47               New York City Campaign Finance Board       9
# 48                    Department of Sanitation (DSNY)       9
# 49             Department of Environmental Protection       9
# 50                      Fire Department New York City       8
# 51  Mayor’s Office of Climate and Environmental Ju...       6
# 52                           Police Department (NYPD)       5
# 53  Mayor's Office of Operations and Mayor's Offic...       4
# 54          Office of Environmental Remediation (OER)       4
# 55                       Department of Transportation       2
# 56                  Manhattan Borough President (MBP)       2
# 57                      Department of Education (DOE)       2
# 58                  Department of Investigation (DOI)       2
# 59                     Department of Correction (DOC)       1

# %%
# examine last four agencies
(df
 .groupby(by='attribution')['count']
 .sum()
 .sort_values(ascending=False)
 .reset_index()
 .iloc[60:, :]
)
# Out:
#                                       attribution  count
# 60  Office of the Staten Island Borough President      1
# 61    Mayor's Office of Management & Budget (OMB)      1
# 62                                    NYC Service      1
# 63                     Brooklyn Borough President      1

# %%
# count of values in columns by dataset
(df
 .groupby(by='name')['count']
 .sum()
 .sort_values(ascending=False)
 .head(60)
 .reset_index()
)
# Out:
#                                                  name   count
# 0           311 Service Requests from 2010 to Present  179486
# 1          Pedestrian Mobility Plan Pedestrian Demand  121572
# 2                          311 Web Content - Services   67528
# 3   Street Construction Permits - Stipulations (Hi...   52696
# 4    Housing Maintenance Code Complaints and Problems   37243
# 5                                     Bicycle Parking   34281
# 6                       311 Service Requests for 2007   22238
# 7                       311 Service Requests for 2006   19968
# 8                       311 Service Requests for 2008   19168
# 9                       311 Service Requests for 2005   18203
# 10                      311 Service Requests for 2004   16345
# 11                      311 Service Requests for 2009   14766
# 12                  Daily Tasks Park Cleaning Records    9963
# 13            Street Construction Permits (2013-2021)    7137
# 14         Street Construction Permits (2022-Present)    6205
# 15              Building Elevation and Subgrade (BES)    5667
# 16           DOB NOW: Build – Job Application Filings    3900
# 17                                   Bus Stop Shelter    3199
# 18             Accessible Pedestrian Signal Locations    3034
# 19                      NYCEM Emergency Notifications    2962
# 20        Register of Community Board Budget Requests    2542
# 21                               Harbor Water Quality    2522
# 22                                  Seating Locations    2428
# 23                           Vendor List by Commodity    2219
# 24                  City Bench Locations (Historical)    2098
# 25                        DOB Job Application Filings    2044
# 26                 OATH Hearings Division Case Status    1601
# 27  Hazard Mitigation Plan - Mitigation Actions Da...    1594
# 28                     Trade Waste Broker Registrants    1542
# 29  Asset Management Parks System (AMPS) - Work Or...    1392
# 30                          Forestry Service Requests    1337
# 31                                 City Record Online    1170
# 32                   NYC Council Constituent Services    1109
# 33                                 DOB ECB Violations    1073
# 34                                DOB Permit Issuance    1059
# 35  NYC Historical Vital Records: Index to Digitiz...    1021
# 36           Capital Project Detail Data - Milestones     951
# 37              Capital Project Schedules and Budgets     877
# 38                             WalkNYC Sign Locations     863
# 39  Street Construction Inspections and Corrective...     805
# 40  NYC Historical Vital Records: Index to Digitiz...     729
# 41         Street Construction Permits - Stipulations     727
# 42  Historical Medallion Drivers – Passenger Assis...     710
# 43    Parks Inspection Program – Conditions & Hazards     705
# 44  Exclusive Pedestrian Signal (Barnes Dance) Loc...     659
# 45                            Street Sign Work Orders     572
# 46                     Historical DOB Permit Issuance     565
# 47                Citywide Payroll Data (Fiscal Year)     560
# 48             Property Valuation and Assessment Data     557
# 49  Asset Management Parks System (AMPS) – Transac...     541
# 50    Asset Management Parks System (AMPS) – Comments     536
# 51  NYC Historical Vital Records: Index to Digitiz...     527
# 52                               Forestry Work Orders     515
# 53     Real Time Passenger Information Sign Locations     494
# 54                  DOB NOW: Build – Approved Permits     485
# 55                                     Expense Budget     455
# 56  Property Valuation and Assessment Data Tax Cla...     441
# 57  Parks Supervisor Inspections - Inspection Results     353
# 58  Historical Medallion Drivers – Passenger Assis...     352
# 59                                         NewsStands     351

# %%
# count of values in columns by agency and dataset
(df
 .groupby(by=['attribution', 'name'])['count']
 .sum()
 .sort_values(ascending=False)
 .head(60)
 .reset_index()
)
# Out:
#                                           attribution  \
# 0                                                 311
# 1                  Department of Transportation (DOT)
# 2                                                 311
# 3                  Department of Transportation (DOT)
# 4   Department of Housing Preservation & Developme...
# 5                  Department of Transportation (DOT)
# 6                                                 311
# 7                                                 311
# 8                                                 311
# 9                                                 311
# 10                                                311
# 11                                                311
# 12           Department of Parks and Recreation (DPR)
# 13                 Department of Transportation (DOT)
# 14                 Department of Transportation (DOT)
# 15                  Department of City Planning (DCP)
# 16                      Department of Buildings (DOB)
# 17                   NYC Department of Transportation
# 18                 Department of Transportation (DOT)
# 19                   NYC Emergency Management (NYCEM)
# 20      New York City Office of Management and Budget
# 21       Department of Environmental Protection (DEP)
# 22                 Department of Transportation (DOT)
# 23         Mayor's Office of Contract Services (MOCS)
# 24                 Department of Transportation (DOT)
# 25                      Department of Buildings (DOB)
# 26  Office of Administrative Trials and Hearings (...
# 27                   NYC Emergency Management (NYCEM)
# 28                      Business Integrity Commission
# 29           Department of Parks and Recreation (DPR)
# 30           Department of Parks and Recreation (DPR)
# 31  Department of Citywide Administrative Services...
# 32                       New York City Council (NYCC)
# 33                      Department of Buildings (DOB)
# 34                      Department of Buildings (DOB)
# 35  Department of Records and Information Services...
# 36      Mayor’s Office of Management and Budget (OMB)
# 37                School Construction Authority (SCA)
# 38                 Department of Transportation (DOT)
# 39                 Department of Transportation (DOT)
# 40  Department of Records and Information Services...
# 41                 Department of Transportation (DOT)
# 42                Taxi and Limousine Commission (TLC)
# 43           Department of Parks and Recreation (DPR)
# 44                 Department of Transportation (DOT)
# 45                 Department of Transportation (DOT)
# 46             Office of Payroll Administration (OPA)
# 47                        Department of Finance (DOF)
# 48           Department of Parks and Recreation (DPR)
# 49           Department of Parks and Recreation (DPR)
# 50  Department of Records and Information Services...
# 51           Department of Parks and Recreation (DPR)
# 52                 Department of Transportation (DOT)
# 53                      Department of Buildings (DOB)
# 54        Mayor’s Office of Management & Budget (OMB)
# 55                        Department of Finance (DOF)
# 56                                          NYC Parks
# 57                Taxi and Limousine Commission (TLC)
# 58      Mayor’s Office of Management and Budget (OMB)
# 59  Department of Citywide Administrative Services...
#
#                                                  name   count
# 0           311 Service Requests from 2010 to Present  179486
# 1          Pedestrian Mobility Plan Pedestrian Demand  121572
# 2                          311 Web Content - Services   67528
# 3   Street Construction Permits - Stipulations (Hi...   52696
# 4    Housing Maintenance Code Complaints and Problems   37243
# 5                                     Bicycle Parking   34281
# 6                       311 Service Requests for 2007   22238
# 7                       311 Service Requests for 2006   19968
# 8                       311 Service Requests for 2008   19168
# 9                       311 Service Requests for 2005   18203
# 10                      311 Service Requests for 2004   16345
# 11                      311 Service Requests for 2009   14766
# 12                  Daily Tasks Park Cleaning Records    9963
# 13            Street Construction Permits (2013-2021)    7137
# 14         Street Construction Permits (2022-Present)    6205
# 15              Building Elevation and Subgrade (BES)    5667
# 16           DOB NOW: Build – Job Application Filings    3900
# 17                                   Bus Stop Shelter    3199
# 18             Accessible Pedestrian Signal Locations    3034
# 19                      NYCEM Emergency Notifications    2962
# 20        Register of Community Board Budget Requests    2542
# 21                               Harbor Water Quality    2522
# 22                                  Seating Locations    2428
# 23                           Vendor List by Commodity    2219
# 24                  City Bench Locations (Historical)    2098
# 25                        DOB Job Application Filings    2044
# 26                 OATH Hearings Division Case Status    1601
# 27  Hazard Mitigation Plan - Mitigation Actions Da...    1594
# 28                     Trade Waste Broker Registrants    1542
# 29  Asset Management Parks System (AMPS) - Work Or...    1392
# 30                          Forestry Service Requests    1337
# 31                                 City Record Online    1170
# 32                   NYC Council Constituent Services    1109
# 33                                 DOB ECB Violations    1073
# 34                                DOB Permit Issuance    1059
# 35  NYC Historical Vital Records: Index to Digitiz...    1021
# 36           Capital Project Detail Data - Milestones     951
# 37              Capital Project Schedules and Budgets     877
# 38                             WalkNYC Sign Locations     863
# 39  Street Construction Inspections and Corrective...     805
# 40  NYC Historical Vital Records: Index to Digitiz...     729
# 41         Street Construction Permits - Stipulations     727
# 42  Historical Medallion Drivers – Passenger Assis...     710
# 43    Parks Inspection Program – Conditions & Hazards     705
# 44  Exclusive Pedestrian Signal (Barnes Dance) Loc...     659
# 45                            Street Sign Work Orders     572
# 46                Citywide Payroll Data (Fiscal Year)     560
# 47             Property Valuation and Assessment Data     557
# 48  Asset Management Parks System (AMPS) – Transac...     541
# 49    Asset Management Parks System (AMPS) – Comments     536
# 50  NYC Historical Vital Records: Index to Digitiz...     527
# 51                               Forestry Work Orders     515
# 52     Real Time Passenger Information Sign Locations     494
# 53                  DOB NOW: Build – Approved Permits     485
# 54                                     Expense Budget     455
# 55  Property Valuation and Assessment Data Tax Cla...     441
# 56  Parks Supervisor Inspections - Inspection Results     353
# 57  Historical Medallion Drivers – Passenger Assis...     352
# 58              Capital Project Detail Data - Dollars     342
# 59                                         Civil List     314

# %%
# count of values in columns by agency, dataset and column
(df
 .groupby(by=['attribution', 'name', 'column'])['count']
 .sum()
 .sort_values(ascending=False)
 .head(60)
 .reset_index()
)
# Out:
#                                           attribution  \
# 0                                                 311
# 1                  Department of Transportation (DOT)
# 2   Department of Housing Preservation & Developme...
# 3                                                 311
# 4                  Department of Transportation (DOT)
# 5                  Department of Transportation (DOT)
# 6                  Department of Transportation (DOT)
# 7                                                 311
# 8                                                 311
# 9                                                 311
# 10                                                311
# 11                                                311
# 12                                                311
# 13                                                311
# 14           Department of Parks and Recreation (DPR)
# 15                                                311
# 16                                                311
# 17                 Department of Transportation (DOT)
# 18                 Department of Transportation (DOT)
# 19                  Department of City Planning (DCP)
# 20                                                311
# 21                      Department of Buildings (DOB)
# 22                   NYC Department of Transportation
# 23                 Department of Transportation (DOT)
# 24       Department of Environmental Protection (DEP)
# 25      New York City Office of Management and Budget
# 26                 Department of Transportation (DOT)
# 27         Mayor's Office of Contract Services (MOCS)
# 28                 Department of Transportation (DOT)
# 29                      Department of Buildings (DOB)
# 30                   NYC Emergency Management (NYCEM)
# 31                      Business Integrity Commission
# 32           Department of Parks and Recreation (DPR)
# 33                   NYC Emergency Management (NYCEM)
# 34           Department of Parks and Recreation (DPR)
# 35                       New York City Council (NYCC)
# 36                      Department of Buildings (DOB)
# 37  Department of Records and Information Services...
# 38  Office of Administrative Trials and Hearings (...
# 39                School Construction Authority (SCA)
# 40                 Department of Transportation (DOT)
# 41      Mayor’s Office of Management and Budget (OMB)
# 42                 Department of Transportation (DOT)
# 43                 Department of Transportation (DOT)
# 44  Department of Records and Information Services...
# 45                Taxi and Limousine Commission (TLC)
# 46                 Department of Transportation (DOT)
# 47                   NYC Emergency Management (NYCEM)
# 48           Department of Parks and Recreation (DPR)
# 49                 Department of Transportation (DOT)
# 50  Department of Citywide Administrative Services...
# 51                 Department of Transportation (DOT)
# 52             Office of Payroll Administration (OPA)
# 53                        Department of Finance (DOF)
# 54           Department of Parks and Recreation (DPR)
# 55  Department of Records and Information Services...
# 56           Department of Parks and Recreation (DPR)
# 57                 Department of Transportation (DOT)
# 58           Department of Parks and Recreation (DPR)
# 59                      Department of Buildings (DOB)
#
#                                                  name  \
# 0           311 Service Requests from 2010 to Present
# 1          Pedestrian Mobility Plan Pedestrian Demand
# 2    Housing Maintenance Code Complaints and Problems
# 3                          311 Web Content - Services
# 4                                     Bicycle Parking
# 5   Street Construction Permits - Stipulations (Hi...
# 6   Street Construction Permits - Stipulations (Hi...
# 7                       311 Service Requests for 2007
# 8                       311 Service Requests for 2006
# 9                       311 Service Requests for 2008
# 10                      311 Service Requests for 2005
# 11                      311 Service Requests for 2004
# 12                         311 Web Content - Services
# 13                      311 Service Requests for 2009
# 14                  Daily Tasks Park Cleaning Records
# 15                         311 Web Content - Services
# 16                         311 Web Content - Services
# 17            Street Construction Permits (2013-2021)
# 18         Street Construction Permits (2022-Present)
# 19              Building Elevation and Subgrade (BES)
# 20          311 Service Requests from 2010 to Present
# 21           DOB NOW: Build – Job Application Filings
# 22                                   Bus Stop Shelter
# 23             Accessible Pedestrian Signal Locations
# 24                               Harbor Water Quality
# 25        Register of Community Board Budget Requests
# 26                                  Seating Locations
# 27                           Vendor List by Commodity
# 28                  City Bench Locations (Historical)
# 29                        DOB Job Application Filings
# 30                      NYCEM Emergency Notifications
# 31                     Trade Waste Broker Registrants
# 32  Asset Management Parks System (AMPS) - Work Or...
# 33                      NYCEM Emergency Notifications
# 34                          Forestry Service Requests
# 35                   NYC Council Constituent Services
# 36                                 DOB ECB Violations
# 37  NYC Historical Vital Records: Index to Digitiz...
# 38                 OATH Hearings Division Case Status
# 39              Capital Project Schedules and Budgets
# 40                             WalkNYC Sign Locations
# 41           Capital Project Detail Data - Milestones
# 42            Street Construction Permits (2013-2021)
# 43         Street Construction Permits - Stipulations
# 44  NYC Historical Vital Records: Index to Digitiz...
# 45  Historical Medallion Drivers – Passenger Assis...
# 46  Street Construction Inspections and Corrective...
# 47  Hazard Mitigation Plan - Mitigation Actions Da...
# 48    Parks Inspection Program – Conditions & Hazards
# 49  Exclusive Pedestrian Signal (Barnes Dance) Loc...
# 50                                 City Record Online
# 51                            Street Sign Work Orders
# 52                Citywide Payroll Data (Fiscal Year)
# 53             Property Valuation and Assessment Data
# 54    Asset Management Parks System (AMPS) – Comments
# 55  NYC Historical Vital Records: Index to Digitiz...
# 56  Asset Management Parks System (AMPS) – Transac...
# 57     Real Time Passenger Information Sign Locations
# 58                               Forestry Work Orders
# 59                                DOB Permit Issuance
#
#                                    column   count
# 0                              descriptor  174252
# 1                                FEMAFldT  121572
# 2                            problem_code   37237
# 3                            web_keywords   35090
# 4                                FEMAFldT   34281
# 5                           stipulationid   26348
# 6                     stipulationfulltext   26348
# 7                              descriptor   22238
# 8                              descriptor   19968
# 9                              descriptor   19168
# 10                             descriptor   18203
# 11                             descriptor   16345
# 12                   detailed_description   15800
# 13                             descriptor   14766
# 14                               signname    9963
# 15                      brief_description    9583
# 16                           service_name    7055
# 17                  permitpurposecomments    6225
# 18                  permitpurposecomments    5922
# 19                                 notes2    5667
# 20                 resolution_description    5204
# 21           SpecialInspectionRequirement    3900
# 22                               FEMAFldT    3199
# 23                               FEMAFldT    3034
# 24  Current Direction (Current Direction)    2513
# 25                           Explanation     2512
# 26                               FEMAFldT    2428
# 27                              commodity    2147
# 28                               FEMAFldT    2098
# 29                        job_description    1919
# 30                             Email Body    1629
# 31                                  EMAIL    1542
# 32                               evt_desc    1381
# 33                     Notification Title    1333
# 34                       ComplaintDetails    1229
# 35                             DESCRIPTOR    1109
# 36                  violation_description    1062
# 37                              last_name    1021
# 38                      violation_details    1008
# 39                    Project Description     877
# 40                               FEMAFldT     863
# 41                          PROJECT_DESCR     831
# 42                   specificstipulations     762
# 43                    stipulationfulltext     727
# 44                              last_name     726
# 45                                   name     710
# 46                      inspectionremarks     703
# 47                      Hazards Addressed     696
# 48                      Location/Comments     667
# 49                               FEMAFldT     659
# 50                 AdditionalDescription1     579
# 51                       sign_description     568
# 52                              last_name     560
# 53                                  owner     557
# 54                               ADD_TEXT     535
# 55                              last_name     527
# 56                               par_desc     519
# 57                               FEMAFldT     494
# 58                        locationdetails     491
# 59                  permittee_s_last_name     490

# %%
# count of values in columns by agency, dataset, column and column value
(df
 .groupby(by=['attribution', 'name', 'column', 'value'])['count']
 .sum()
 .sort_values(ascending=False)
 .head(60)
 .reset_index()
)
# Out:
#                                           attribution  \
# 0                                                 311
# 1                  Department of Transportation (DOT)
# 2                                                 311
# 3   Department of Housing Preservation & Developme...
# 4                  Department of Transportation (DOT)
# 5                  Department of Transportation (DOT)
# 6                  Department of Transportation (DOT)
# 7                                                 311
# 8                                                 311
# 9                                                 311
# 10                                                311
# 11                                                311
# 12                                                311
# 13           Department of Parks and Recreation (DPR)
# 14                                                311
# 15                  Department of City Planning (DCP)
# 16                                                311
# 17                 Department of Transportation (DOT)
# 18                                                311
# 19                                                311
# 20                                                311
# 21                   NYC Department of Transportation
# 22                 Department of Transportation (DOT)
# 23                                                311
# 24                 Department of Transportation (DOT)
# 25                                                311
# 26       Department of Environmental Protection (DEP)
# 27                 Department of Transportation (DOT)
# 28                                                311
# 29                 Department of Transportation (DOT)
# 30                                                311
# 31                 Department of Transportation (DOT)
# 32                      Business Integrity Commission
# 33                                                311
# 34                 Department of Transportation (DOT)
# 35                                                311
# 36                                                311
# 37                                                311
# 38                                                311
# 39                                                311
# 40                                                311
# 41                                                311
# 42                                                311
# 43                                                311
# 44                                                311
# 45                                                311
# 46                                                311
# 47                                                311
# 48                                                311
# 49                                                311
# 50                                                311
# 51                                                311
# 52                                                311
# 53                                                311
# 54                                                311
# 55                                                311
# 56                                                311
# 57                                                311
# 58                                                311
# 59                                                311
#
#                                                  name  \
# 0           311 Service Requests from 2010 to Present
# 1          Pedestrian Mobility Plan Pedestrian Demand
# 2           311 Service Requests from 2010 to Present
# 3    Housing Maintenance Code Complaints and Problems
# 4                                     Bicycle Parking
# 5   Street Construction Permits - Stipulations (Hi...
# 6   Street Construction Permits - Stipulations (Hi...
# 7                       311 Service Requests for 2007
# 8                       311 Service Requests for 2006
# 9                       311 Service Requests for 2005
# 10                      311 Service Requests for 2004
# 11                      311 Service Requests for 2008
# 12                      311 Service Requests for 2009
# 13                  Daily Tasks Park Cleaning Records
# 14          311 Service Requests from 2010 to Present
# 15              Building Elevation and Subgrade (BES)
# 16          311 Service Requests from 2010 to Present
# 17         Pedestrian Mobility Plan Pedestrian Demand
# 18                      311 Service Requests for 2008
# 19                      311 Service Requests for 2007
# 20          311 Service Requests from 2010 to Present
# 21                                   Bus Stop Shelter
# 22             Accessible Pedestrian Signal Locations
# 23                      311 Service Requests for 2009
# 24         Pedestrian Mobility Plan Pedestrian Demand
# 25          311 Service Requests from 2010 to Present
# 26                               Harbor Water Quality
# 27                                  Seating Locations
# 28                      311 Service Requests for 2006
# 29                  City Bench Locations (Historical)
# 30                      311 Service Requests for 2005
# 31         Pedestrian Mobility Plan Pedestrian Demand
# 32                     Trade Waste Broker Registrants
# 33                      311 Service Requests for 2004
# 34         Street Construction Permits (2022-Present)
# 35                         311 Web Content - Services
# 36                         311 Web Content - Services
# 37                         311 Web Content - Services
# 38                         311 Web Content - Services
# 39                         311 Web Content - Services
# 40                         311 Web Content - Services
# 41                         311 Web Content - Services
# 42                         311 Web Content - Services
# 43                         311 Web Content - Services
# 44                         311 Web Content - Services
# 45                         311 Web Content - Services
# 46                         311 Web Content - Services
# 47                         311 Web Content - Services
# 48                         311 Web Content - Services
# 49                         311 Web Content - Services
# 50                         311 Web Content - Services
# 51                         311 Web Content - Services
# 52                         311 Web Content - Services
# 53                         311 Web Content - Services
# 54                         311 Web Content - Services
# 55                         311 Web Content - Services
# 56                         311 Web Content - Services
# 57                         311 Web Content - Services
# 58                         311 Web Content - Services
# 59                         311 Web Content - Services
#
#                                    column  \
# 0                              descriptor
# 1                                FEMAFldT
# 2                              descriptor
# 3                            problem_code
# 4                                FEMAFldT
# 5                           stipulationid
# 6                     stipulationfulltext
# 7                              descriptor
# 8                              descriptor
# 9                              descriptor
# 10                             descriptor
# 11                             descriptor
# 12                             descriptor
# 13                               signname
# 14                             descriptor
# 15                                 notes2
# 16                 resolution_description
# 17                               FEMAFldT
# 18                             descriptor
# 19                             descriptor
# 20                             descriptor
# 21                               FEMAFldT
# 22                               FEMAFldT
# 23                             descriptor
# 24                               FEMAFldT
# 25                             descriptor
# 26  Current Direction (Current Direction)
# 27                               FEMAFldT
# 28                             descriptor
# 29                               FEMAFldT
# 30                             descriptor
# 31                               FEMAFldT
# 32                                  EMAIL
# 33                             descriptor
# 34                  permitpurposecomments
# 35                           web_keywords
# 36                           web_keywords
# 37                           web_keywords
# 38                           web_keywords
# 39                           service_name
# 40                           web_keywords
# 41                           web_keywords
# 42                           web_keywords
# 43                           web_keywords
# 44                      brief_description
# 45                   detailed_description
# 46                   detailed_description
# 47                   detailed_description
# 48                   detailed_description
# 49                   detailed_description
# 50                           service_name
# 51                           service_name
# 52                           web_keywords
# 53                      brief_description
# 54                           service_name
# 55                      brief_description
# 56                      brief_description
# 57                      brief_description
# 58                      brief_description
# 59                      brief_description
#
#                                                 value   count
# 0    Catch Basin Clogged/Flooding (Use Comments) (SC)  118865
# 1                        AREA OF MINIMAL FLOOD HAZARD  111949
# 2                                Street Flooding (SJ)   41154
# 3                              FIXTURE WET OR FLOODED   37237
# 4                        AREA OF MINIMAL FLOOD HAZARD   33396
# 5                                              FLOODA   26348
# 6                     NYC OEM EVACUATION FLOOD ZONE A   26348
# 7    Catch Basin Clogged/Flooding (Use Comments) (SC)   17628
# 8    Catch Basin Clogged/Flooding (Use Comments) (SC)   16713
# 9    Catch Basin Clogged/Flooding (Use Comments) (SC)   14980
# 10   Catch Basin Clogged/Flooding (Use Comments) (SC)   14427
# 11   Catch Basin Clogged/Flooding (Use Comments) (SC)   14016
# 12   Catch Basin Clogged/Flooding (Use Comments) (SC)   10367
# 13                              X061 | Flood Triangle    9963
# 14                               Flood Light Lamp Out    6612
# 15  Fully Enclosed Ground floor for Apartment Lobb...    4469
# 16  The Department of Environmental Protection inv...    3827
# 17                 0.2 PCT ANNUAL CHANCE FLOOD HAZARD    3751
# 18                               Street Flooding (SJ)    3461
# 19                               Street Flooding (SJ)    3270
# 20                              Highway Flooding (SH)    3189
# 21                       AREA OF MINIMAL FLOOD HAZARD    3064
# 22                       AREA OF MINIMAL FLOOD HAZARD    2935
# 23                               Street Flooding (SJ)    2810
# 24  0.2 PCT ANNUAL CHANCE FLOOD HAZARD,AREA OF MIN...    2665
# 25                           Flood Light Lamp Cycling    2615
# 26                                              Flood    2419
# 27  AREA OF MINIMAL FLOOD HAZARD, AREA OF MINIMAL ...    2357
# 28                               Street Flooding (SJ)    2090
# 29                       AREA OF MINIMAL FLOOD HAZARD    2030
# 30                               Street Flooding (SJ)    1899
# 31                ,0.2 PCT ANNUAL CHANCE FLOOD HAZARD    1757
# 32                            kflood@astorcompany.com    1542
# 33                               Street Flooding (SJ)    1535
# 34  Installation of Sanitary and Storm Sewers, Flo...    1370
# 35  FEMA, flood, letter, notice, flood insurance, ...    1264
# 36  acceleration, attack, break, building, chemica...    1264
# 37  FEMA, A Zone, V Zone, floodplain, flood, flood...    1264
# 38  DCAS, DEP, DOT, DSNY, DoITT, DORIS, Ops, Depar...    1264
# 39                              Waterfront Flood Zone    1264
# 40  blue, belt, staten, island, statan, swamp, wet...    1264
# 41  Know, Your, Zone, window, stickers, evacuation...    1264
# 42  FEMA, flood, insurance, floodplain, zone, maps...    1264
# 43  ready, redi, readyness, readiness, rediness, g...    1264
# 44  Get a guide on what to do in an emergency, inc...    1264
# 45  <p>New flood insurance policy rates will take ...    1264
# 46  The City accepts reports of damaged or dirty a...    1264
# 47  The City provides assistance to businesses tha...    1264
# 48  The City provides information on flood zone de...    1264
# 49  You can report a construction or excavation pr...    1264
# 50                             FEMA - Flood Insurance    1264
# 51                   FEMA - Flood Insurance Rate Maps    1264
# 52  cleaning, full, sewer, drain, street, embankme...    1264
# 53  Get flood insurance requirements and building ...    1264
# 54                         Flooding Street or Highway    1264
# 55  Report street or highway flooding or a manhole...    1264
# 56  Report a sewer backup or get information about...    1264
# 57  Get information on flood insurance policy rate...    1264
# 58  Get information about flood zone designations ...    1264
# 59             Get information about flood insurance.    1264
