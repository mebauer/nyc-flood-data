# %% [markdown]
# # Retrieve Dataset IDs and Column Names on NYC Open Data
# Author: Mark Bauer

# %% [markdown]
# ### **Goal: Retrive dataset IDs and column names from NYC Open Data. We will use this CSV to programmatically loop through datasets to search for the word *flood*.**

# %% [markdown]
# # Importing Libraries

# %%
# importing libraries
import pandas as pd
import numpy as np
from sodapy import Socrata
import requests
import time

# %% [markdown]
# Documention for installing watermark: https://github.com/rasbt/watermark.

# %%
# performed for reproducibility
# %reload_ext watermark
# %watermark -t -d -v -p pandas,sodapy
# Out:
# Python implementation: CPython
# Python version       : 3.11.0
# IPython version      : 8.6.0
#
# pandas: 1.5.1
# sodapy: 2.2.0

# %% [markdown]
# # Socrata API
# I used the Socrata API to retrieve metadata for datasets hosted on NYC Open Data. Documentation can be found here: https://dev.socrata.com/. Additionally, I used sodapy, the python client for the Socrata API, to query the metadata.
#
# We'll use this API to gather all the datasets on NYC Open Data.

# %% [markdown]
# ### Note:
# `WARNING:root:Requests made without an app_token will be subject to strict throttling limits.`
#
# Read more from the SODA documentation here: https://dev.socrata.com/docs/app-tokens.html

# %%
ls
# Out:
# cover-photo.ipynb        metadata-analysis.ipynb
# dataset-analysis.ipynb   search-text-flood.ipynb

# %%
# source domain for NYC Open Data on Socrata
socrata_domain = 'data.cityofnewyork.us'

# initialize Socrata object to fetch data
client = Socrata(
    domain=socrata_domain,
    app_token=None,
    timeout=10000
)

print(client)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# <sodapy.socrata.Socrata object at 0x111b39250>

# %%
# Discovery API
url = 'https://api.us.socrata.com/api/catalog/v1?search_context=data.cityofnewyork.us&limit=50000'

# fetch the JSON data from the web
response = requests.get(url)

# parse the JSON response
data_dict = response.json() 

# preview keys    
data_dict.keys()
# Out:
# dict_keys(['results', 'resultSetSize', 'timings', 'warnings'])

# %%
# convert into df
df = pd.DataFrame.from_records(data_dict['results'])

# sanity check
print(df.shape)
df.head()
# Out:
# (3199, 8)
#                                             resource  \
# 0  {'name': 'For Hire Vehicles (FHV) - Active', '...
# 1  {'name': 'Civil Service List (Active)', 'id': ...
# 2  {'name': 'DOB Job Application Filings', 'id': ...
# 3  {'name': 'TLC New Driver Application Status', ...
# 4  {'name': 'For Hire Vehicles (FHV) - Active Dri...
#
#                                       classification  \
# 0  {'categories': [], 'tags': [], 'domain_categor...
# 1  {'categories': [], 'tags': [], 'domain_categor...
# 2  {'categories': [], 'tags': [], 'domain_categor...
# 3  {'categories': [], 'tags': [], 'domain_categor...
# 4  {'categories': [], 'tags': [], 'domain_categor...
#
#                               metadata  \
# 0  {'domain': 'data.cityofnewyork.us'}
# 1  {'domain': 'data.cityofnewyork.us'}
# 2  {'domain': 'data.cityofnewyork.us'}
# 3  {'domain': 'data.cityofnewyork.us'}
# 4  {'domain': 'data.cityofnewyork.us'}
#
#                                    permalink  \
# 0  https://data.cityofnewyork.us/d/8wbx-tsch
# 1  https://data.cityofnewyork.us/d/vx8i-nprf
# 2  https://data.cityofnewyork.us/d/ic3t-wcy2
# 3  https://data.cityofnewyork.us/d/dpec-ucu7
# 4  https://data.cityofnewyork.us/d/xjfq-wh2d
#
#                                                 link  \
# 0  https://data.cityofnewyork.us/Transportation/F...
# 1  https://data.cityofnewyork.us/City-Government/...
# 2  https://data.cityofnewyork.us/Housing-Developm...
# 3  https://data.cityofnewyork.us/Transportation/T...
# 4  https://data.cityofnewyork.us/Transportation/F...
#
#                                                owner  \
# 0  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 1  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 2  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 3  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 4  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
#
#                                              creator preview_image_url
# 0  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 1  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 2  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 3  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 4  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN

# %%
# convert resource key to a dataframe
df = pd.DataFrame.from_records(df['resource'])

# sanity check
print(df.shape)
df.head()
# Out:
# (3199, 27)
#                                        name         id resource_name  \
# 0          For Hire Vehicles (FHV) - Active  8wbx-tsch          None
# 1               Civil Service List (Active)  vx8i-nprf          None
# 2               DOB Job Application Filings  ic3t-wcy2          None
# 3         TLC New Driver Application Status  dpec-ucu7          None
# 4  For Hire Vehicles (FHV) - Active Drivers  xjfq-wh2d          None
#
#   parent_fxf                                        description  \
# 0         []  <b>PLEASE NOTE:</b> This dataset, which includ...
# 1         []  A Civil Service List consists of all candidate...
# 2         []  This dataset contains all job applications sub...
# 3         []  THIS DATASET IS UPDATED SEVERAL TIMES PER DAY....
# 4         []  <b>PLEASE NOTE:</b> This dataset, which includ...
#
#                                          attribution attribution_link  \
# 0                Taxi and Limousine Commission (TLC)             None
# 1  Department of Citywide Administrative Services...             None
# 2                      Department of Buildings (DOB)             None
# 3                Taxi and Limousine Commission (TLC)             None
# 4                Taxi and Limousine Commission (TLC)             None
#
#   contact_email     type                 updatedAt  ...  \
# 0          None  dataset  2025-01-24T19:57:07.000Z  ...
# 1          None  dataset  2025-01-24T14:14:49.000Z  ...
# 2          None  dataset  2025-01-24T21:10:03.000Z  ...
# 3          None  dataset  2025-01-25T11:03:13.000Z  ...
# 4          None  dataset  2025-01-24T19:58:30.000Z  ...
#
#                                  columns_description  \
# 0  [Base Number, Vehicle Year, Date Suspension or...
# 1  [A “Sibling Legacy Credit” is additional credi...
# 2  [Loft Board, 1= Manhattan, 2= Bronx, 3 = Brook...
# 3  [This is the number linked to your application...
# 4  [Driver Name\n\n, Last Date Updated, Last Time...
#
#                                       columns_format download_count  \
# 0  [{'displayStyle': 'plain', 'align': 'left'}, {...         539625
# 1  [{'displayStyle': 'plain', 'align': 'left'}, {...          69765
# 2  [{'align': 'right'}, {'align': 'right'}, {'ali...          60242
# 3  [{'precisionStyle': 'standard', 'noCommas': 't...          39718
# 4  [{'displayStyle': 'plain', 'align': 'left'}, {...         425132
#
#   provenance lens_view_type lens_display_type locked blob_mime_type  \
# 0   official        tabular             table  False           None
# 1   official        tabular             table  False           None
# 2   official        tabular             table  False           None
# 3   official        tabular             table  False           None
# 4   official        tabular             table  False           None
#
#   hide_from_data_json          publication_date
# 0               False  2021-04-05T13:20:47.000Z
# 1               False  2024-01-12T16:15:05.000Z
# 2               False  2020-06-22T18:23:35.000Z
# 3               False  2019-12-17T18:44:57.000Z
# 4               False  2024-01-11T19:58:17.000Z
#
# [5 rows x 27 columns]

# %%
# preview columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3199 entries, 0 to 3198
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 3199 non-null   object
#  1   id                   3199 non-null   object
#  2   resource_name        0 non-null      object
#  3   parent_fxf           3199 non-null   object
#  4   description          3199 non-null   object
#  5   attribution          3129 non-null   object
#  6   attribution_link     495 non-null    object
#  7   contact_email        0 non-null      object
#  8   type                 3199 non-null   object
#  9   updatedAt            3199 non-null   object
#  10  createdAt            3199 non-null   object
#  11  metadata_updated_at  3199 non-null   object
#  12  data_updated_at      3028 non-null   object
#  13  page_views           3199 non-null   object
#  14  columns_name         3199 non-null   object
#  15  columns_field_name   3199 non-null   object
#  16  columns_datatype     3199 non-null   object
#  17  columns_description  3199 non-null   object
#  18  columns_format       3199 non-null   object
#  19  download_count       3199 non-null   int64
#  20  provenance           3199 non-null   object
#  21  lens_view_type       3199 non-null   object
#  22  lens_display_type    3199 non-null   object
#  23  locked               3199 non-null   bool
#  24  blob_mime_type       167 non-null    object
#  25  hide_from_data_json  3199 non-null   bool
#  26  publication_date     3174 non-null   object
# dtypes: bool(2), int64(1), object(24)
# memory usage: 631.2+ KB

# %%
# review dataset types, we only want datasets
df['type'].value_counts()
# Out:
# dataset          2570
# map               287
# file              167
# href              147
# filter             24
# story               2
# chart               1
# visualization       1
# Name: type, dtype: int64

# %%
# we only want datasets
df = (
    df
    .loc[df['type'] == 'dataset']
    .reset_index(drop=True)
)

# sanity check
print(df.shape)
df.head()
# Out:
# (2570, 27)
#                                        name         id resource_name  \
# 0          For Hire Vehicles (FHV) - Active  8wbx-tsch          None
# 1               Civil Service List (Active)  vx8i-nprf          None
# 2               DOB Job Application Filings  ic3t-wcy2          None
# 3         TLC New Driver Application Status  dpec-ucu7          None
# 4  For Hire Vehicles (FHV) - Active Drivers  xjfq-wh2d          None
#
#   parent_fxf                                        description  \
# 0         []  <b>PLEASE NOTE:</b> This dataset, which includ...
# 1         []  A Civil Service List consists of all candidate...
# 2         []  This dataset contains all job applications sub...
# 3         []  THIS DATASET IS UPDATED SEVERAL TIMES PER DAY....
# 4         []  <b>PLEASE NOTE:</b> This dataset, which includ...
#
#                                          attribution attribution_link  \
# 0                Taxi and Limousine Commission (TLC)             None
# 1  Department of Citywide Administrative Services...             None
# 2                      Department of Buildings (DOB)             None
# 3                Taxi and Limousine Commission (TLC)             None
# 4                Taxi and Limousine Commission (TLC)             None
#
#   contact_email     type                 updatedAt  ...  \
# 0          None  dataset  2025-01-24T19:57:07.000Z  ...
# 1          None  dataset  2025-01-24T14:14:49.000Z  ...
# 2          None  dataset  2025-01-24T21:10:03.000Z  ...
# 3          None  dataset  2025-01-25T11:03:13.000Z  ...
# 4          None  dataset  2025-01-24T19:58:30.000Z  ...
#
#                                  columns_description  \
# 0  [Base Number, Vehicle Year, Date Suspension or...
# 1  [A “Sibling Legacy Credit” is additional credi...
# 2  [Loft Board, 1= Manhattan, 2= Bronx, 3 = Brook...
# 3  [This is the number linked to your application...
# 4  [Driver Name\n\n, Last Date Updated, Last Time...
#
#                                       columns_format download_count  \
# 0  [{'displayStyle': 'plain', 'align': 'left'}, {...         539625
# 1  [{'displayStyle': 'plain', 'align': 'left'}, {...          69765
# 2  [{'align': 'right'}, {'align': 'right'}, {'ali...          60242
# 3  [{'precisionStyle': 'standard', 'noCommas': 't...          39718
# 4  [{'displayStyle': 'plain', 'align': 'left'}, {...         425132
#
#   provenance lens_view_type lens_display_type locked blob_mime_type  \
# 0   official        tabular             table  False           None
# 1   official        tabular             table  False           None
# 2   official        tabular             table  False           None
# 3   official        tabular             table  False           None
# 4   official        tabular             table  False           None
#
#   hide_from_data_json          publication_date
# 0               False  2021-04-05T13:20:47.000Z
# 1               False  2024-01-12T16:15:05.000Z
# 2               False  2020-06-22T18:23:35.000Z
# 3               False  2019-12-17T18:44:57.000Z
# 4               False  2024-01-11T19:58:17.000Z
#
# [5 rows x 27 columns]

# %%
# sanity check view type
df['lens_view_type'].value_counts()
# Out:
# tabular    2570
# Name: lens_view_type, dtype: int64

# %%
# sort df by download count ascending order
df = (
    df
    .sort_values(by='id')
    .reset_index(drop=True)
)

# sanity check
print(df.shape)
df.head()
# Out:
# (2570, 27)
#                                                 name         id resource_name  \
# 0   2016-2017 Student Discipline Annual Report - ELL  22rr-ujq3          None
# 1                     2020 DOE High School Directory  23z9-6uk9          None
# 2                  DSNY Special Waste Drop-off Sites  242c-ru4i          None
# 3         Five Year Plan Summary by Capital Category  24nr-gahi          None
# 4  2018-2019 Local Law 120 Public School Athletic...  24ts-hbqj          None
#
#   parent_fxf                                        description  \
# 0         []  Student discipline annual report for English l...
# 1         []  Directory of Department of Education High Scho...
# 2         []  Location of DSNY Special Waste Drop-Off Sites....
# 3         []   Five year plan summary cost by capital category.
# 4         []  Public Schools Athletic League (PSAL) particip...
#
#                                attribution attribution_link contact_email  \
# 0            Department of Education (DOE)             None          None
# 1            Department of Education (DOE)             None          None
# 2                 Department of Sanitation             None          None
# 3  NYC School Construction Authority (SCA)             None          None
# 4            Department of Education (DOE)             None          None
#
#       type                 updatedAt  ...  \
# 0  dataset  2024-11-26T23:15:04.000Z  ...
# 1  dataset  2024-11-26T23:14:03.000Z  ...
# 2  dataset  2025-01-25T11:02:19.000Z  ...
# 3  dataset  2025-01-10T16:06:06.000Z  ...
# 4  dataset  2024-11-26T23:08:02.000Z  ...
#
#                                  columns_description  \
# 0                         [, , , , , , , , , , , , ]
# 1  [, , , , , , , , , , , , , , , , , , , , , , ,...
# 2  [, In ArcGIS, the FID is a system-managed valu...
# 3                                 [, , , , , , , , ]
# 4  [, , , , , , , , , , , , , , , , , , , , , , ,...
#
#                                       columns_format download_count  \
# 0  [{}, {}, {}, {'decimalSeparator': '.', 'groupS...            752
# 1  [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {...           3176
# 2  [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {...           2115
# 3               [{}, {}, {}, {}, {}, {}, {}, {}, {}]           1704
# 4  [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {...            313
#
#   provenance lens_view_type lens_display_type locked blob_mime_type  \
# 0   official        tabular             table  False           None
# 1   official        tabular             table  False           None
# 2   official        tabular             table  False           None
# 3   official        tabular             table  False           None
# 4   official        tabular             table  False           None
#
#   hide_from_data_json          publication_date
# 0               False  2018-06-07T22:21:57.000Z
# 1               False  2019-10-23T22:16:05.000Z
# 2               False  2020-07-24T03:09:55.000Z
# 3               False  2023-12-27T20:28:30.000Z
# 4               False  2022-03-02T21:19:56.000Z
#
# [5 rows x 27 columns]

# %%
field_names_df = df.loc[:, ['id', 'columns_field_name']].explode('columns_field_name')
field_types_df = df.loc[:, ['id', 'columns_datatype']].explode('columns_datatype')

df = (
    pd
    .concat([field_names_df, field_types_df.drop(columns=['id'])], axis=1)
    .reset_index(drop=True)
)

# sanity check
print(df.shape)
df.head()
# Out:
# (59030, 3)
#           id       columns_field_name columns_datatype
# 0  22rr-ujq3       non_ell_expulsions             Text
# 1  22rr-ujq3            location_name             Text
# 2  22rr-ujq3        location_category             Text
# 3  22rr-ujq3  administrative_district           Number
# 4  22rr-ujq3             ell_removals             Text

# %%
df = (
    df
    .loc[df['columns_datatype'] == 'Text']
    .reset_index(drop=True)
)

# sanity check
print(df.shape)
df.head()
# Out:
# (35580, 3)
#           id  columns_field_name columns_datatype
# 0  22rr-ujq3  non_ell_expulsions             Text
# 1  22rr-ujq3       location_name             Text
# 2  22rr-ujq3   location_category             Text
# 3  22rr-ujq3        ell_removals             Text
# 4  22rr-ujq3      ell_expulsions             Text

# %%
# sanity check
df['columns_datatype'].value_counts()
# Out:
# Text    35580
# Name: columns_datatype, dtype: int64

# %%
# number of dataset
df['id'].nunique()
# Out:
# 2434

# %%
# save as a CSV file
df.to_csv('../data/dataset-ids-columns.csv', index=False)

# %%
# sanity check
# %ls ../data/
# Out:
# dataset-ids-columns.csv  flood-datasets.csv
