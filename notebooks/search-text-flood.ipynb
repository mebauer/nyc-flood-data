# %% [markdown]
# # Search Text Flood
# Author: Mark Bauer

# %% [markdown]
# Goal: To search for the text pattern *flood* in every column in every dataset less than 1M rows on NYC Open Data. We'll retreive datasets with more than 1M rows an alternative method.

# %% [markdown]
# # Importing Libraries

# %%
# importing libraries
import pandas as pd
import numpy as np
from sodapy import Socrata
import requests
import time

# %% [markdown]
# Documention for installing watermark: https://github.com/rasbt/watermark.

# %%
# performed for reproducibility
# %reload_ext watermark
# %watermark -t -d -v -p pandas,sodapy
# Out:
# Python implementation: CPython
# Python version       : 3.11.0
# IPython version      : 8.6.0
#
# pandas: 1.5.1
# sodapy: 2.2.0

# %% [markdown]
# # Socrata API
# I used the Socrata API to retrieve metadata for datasets hosted on NYC Open Data. Documentation can be found here: https://dev.socrata.com/. Additionally, I used sodapy, the python client for the Socrata API, to query the metadata.
#
# We'll use this API to gather all the datasets on NYC Open Data.

# %% [markdown]
# ### Note:
# `WARNING:root:Requests made without an app_token will be subject to strict throttling limits.`
#
# Read more from the SODA documentation here: https://dev.socrata.com/docs/app-tokens.html

# %%
# source domain for NYC Open Data on Socrata
socrata_domain = 'data.cityofnewyork.us'

# initialize Socrata object to fetch data
client = Socrata(
    domain=socrata_domain,
    app_token=None,
    timeout=10000
)

print(client)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# <sodapy.socrata.Socrata object at 0x10e86fb50>

# %%
# Discovery API
url = 'https://api.us.socrata.com/api/catalog/v1?search_context=data.cityofnewyork.us&limit=50000'

# fetch the JSON data from the web
response = requests.get(url)

# parse the JSON response
data_dict = response.json() 

# preview keys    
data_dict.keys()
# Out:
# dict_keys(['results', 'resultSetSize', 'timings', 'warnings'])

# %%
# convert into df
df = pd.DataFrame.from_records(data_dict['results'])

# sanity check
print(df.shape)
df.head()
# Out:
# (3240, 8)
#                                             resource  \
# 0  {'name': 'For Hire Vehicles (FHV) - Active', '...
# 1  {'name': 'Civil Service List (Active)', 'id': ...
# 2  {'name': 'DOB Job Application Filings', 'id': ...
# 3  {'name': 'TLC New Driver Application Status', ...
# 4  {'name': 'For Hire Vehicles (FHV) - Active Dri...
#
#                                       classification  \
# 0  {'categories': [], 'tags': [], 'domain_categor...
# 1  {'categories': [], 'tags': [], 'domain_categor...
# 2  {'categories': [], 'tags': [], 'domain_categor...
# 3  {'categories': [], 'tags': [], 'domain_categor...
# 4  {'categories': [], 'tags': [], 'domain_categor...
#
#                               metadata  \
# 0  {'domain': 'data.cityofnewyork.us'}
# 1  {'domain': 'data.cityofnewyork.us'}
# 2  {'domain': 'data.cityofnewyork.us'}
# 3  {'domain': 'data.cityofnewyork.us'}
# 4  {'domain': 'data.cityofnewyork.us'}
#
#                                    permalink  \
# 0  https://data.cityofnewyork.us/d/8wbx-tsch
# 1  https://data.cityofnewyork.us/d/vx8i-nprf
# 2  https://data.cityofnewyork.us/d/ic3t-wcy2
# 3  https://data.cityofnewyork.us/d/dpec-ucu7
# 4  https://data.cityofnewyork.us/d/xjfq-wh2d
#
#                                                 link  \
# 0  https://data.cityofnewyork.us/Transportation/F...
# 1  https://data.cityofnewyork.us/City-Government/...
# 2  https://data.cityofnewyork.us/Housing-Developm...
# 3  https://data.cityofnewyork.us/Transportation/T...
# 4  https://data.cityofnewyork.us/Transportation/F...
#
#                                                owner  \
# 0  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 1  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 2  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 3  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 4  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
#
#                                              creator preview_image_url
# 0  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 1  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 2  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 3  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 4  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN

# %%
# convert resource key to a dataframe
df = pd.DataFrame.from_records(df['resource'])

# sanity check
print(df.shape)
df.head()
# Out:
# (3240, 27)
#                                        name         id resource_name  \
# 0          For Hire Vehicles (FHV) - Active  8wbx-tsch          None
# 1               Civil Service List (Active)  vx8i-nprf          None
# 2               DOB Job Application Filings  ic3t-wcy2          None
# 3         TLC New Driver Application Status  dpec-ucu7          None
# 4  For Hire Vehicles (FHV) - Active Drivers  xjfq-wh2d          None
#
#   parent_fxf                                        description  \
# 0         []  <b>PLEASE NOTE:</b> This dataset, which includ...
# 1         []  A Civil Service List consists of all candidate...
# 2         []  This dataset contains all job applications sub...
# 3         []  THIS DATASET IS UPDATED SEVERAL TIMES PER DAY....
# 4         []  <b>PLEASE NOTE:</b> This dataset, which includ...
#
#                                          attribution attribution_link  \
# 0                Taxi and Limousine Commission (TLC)             None
# 1  Department of Citywide Administrative Services...             None
# 2                      Department of Buildings (DOB)             None
# 3                Taxi and Limousine Commission (TLC)             None
# 4                Taxi and Limousine Commission (TLC)             None
#
#   contact_email     type                 updatedAt  ...  \
# 0          None  dataset  2024-12-29T20:05:32.000Z  ...
# 1          None  dataset  2024-12-27T14:09:28.000Z  ...
# 2          None  dataset  2024-12-29T21:06:44.000Z  ...
# 3          None  dataset  2024-12-29T23:06:31.000Z  ...
# 4          None  dataset  2024-12-29T20:07:08.000Z  ...
#
#                                  columns_description  \
# 0  [Last Time Updated, Certification Date, Base N...
# 1  [A candidate’s last name as it appears on thei...
# 2  [Proposed Dwelling Units, Document Number, Num...
# 3  [This is the number linked to your application...
# 4  [Driver Name\n\n, Last Time Updated, Type of L...
#
#                                       columns_format download_count  \
# 0  [{'displayStyle': 'plain', 'align': 'left'}, {...         535601
# 1  [{'displayStyle': 'plain', 'align': 'left'}, {...          68870
# 2  [{'align': 'right'}, {'align': 'right'}, {'ali...          59754
# 3  [{'precisionStyle': 'standard', 'noCommas': 't...          39667
# 4  [{'displayStyle': 'plain', 'align': 'left'}, {...         421843
#
#   provenance lens_view_type lens_display_type locked blob_mime_type  \
# 0   official        tabular             table  False           None
# 1   official        tabular             table  False           None
# 2   official        tabular             table  False           None
# 3   official        tabular             table  False           None
# 4   official        tabular             table  False           None
#
#   hide_from_data_json          publication_date
# 0               False  2021-04-05T13:20:47.000Z
# 1               False  2024-01-12T16:15:05.000Z
# 2               False  2020-06-22T18:23:35.000Z
# 3               False  2019-12-17T18:44:57.000Z
# 4               False  2024-01-11T19:58:17.000Z
#
# [5 rows x 27 columns]

# %%
# preview columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3240 entries, 0 to 3239
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 3240 non-null   object
#  1   id                   3240 non-null   object
#  2   resource_name        0 non-null      object
#  3   parent_fxf           3240 non-null   object
#  4   description          3240 non-null   object
#  5   attribution          3169 non-null   object
#  6   attribution_link     477 non-null    object
#  7   contact_email        0 non-null      object
#  8   type                 3240 non-null   object
#  9   updatedAt            3240 non-null   object
#  10  createdAt            3240 non-null   object
#  11  metadata_updated_at  3240 non-null   object
#  12  data_updated_at      3063 non-null   object
#  13  page_views           3240 non-null   object
#  14  columns_name         3240 non-null   object
#  15  columns_field_name   3240 non-null   object
#  16  columns_datatype     3240 non-null   object
#  17  columns_description  3240 non-null   object
#  18  columns_format       3240 non-null   object
#  19  download_count       3240 non-null   int64
#  20  provenance           3240 non-null   object
#  21  lens_view_type       3240 non-null   object
#  22  lens_display_type    3240 non-null   object
#  23  locked               3240 non-null   bool
#  24  blob_mime_type       202 non-null    object
#  25  hide_from_data_json  3240 non-null   bool
#  26  publication_date     3215 non-null   object
# dtypes: bool(2), int64(1), object(24)
# memory usage: 639.3+ KB

# %%
# review dataset types, we only want datasets
df['type'].value_counts()
# Out:
# dataset          2559
# map               339
# file              167
# href              147
# filter             24
# story               2
# chart               1
# visualization       1
# Name: type, dtype: int64

# %%
# we only want datasets
df = (
    df
    .loc[df['type'] == 'dataset']
    .reset_index(drop=True)
)

# sanity check
print(df.shape)
df.head()
# Out:
# (2559, 27)
#                                        name         id resource_name  \
# 0          For Hire Vehicles (FHV) - Active  8wbx-tsch          None
# 1               Civil Service List (Active)  vx8i-nprf          None
# 2               DOB Job Application Filings  ic3t-wcy2          None
# 3         TLC New Driver Application Status  dpec-ucu7          None
# 4  For Hire Vehicles (FHV) - Active Drivers  xjfq-wh2d          None
#
#   parent_fxf                                        description  \
# 0         []  <b>PLEASE NOTE:</b> This dataset, which includ...
# 1         []  A Civil Service List consists of all candidate...
# 2         []  This dataset contains all job applications sub...
# 3         []  THIS DATASET IS UPDATED SEVERAL TIMES PER DAY....
# 4         []  <b>PLEASE NOTE:</b> This dataset, which includ...
#
#                                          attribution attribution_link  \
# 0                Taxi and Limousine Commission (TLC)             None
# 1  Department of Citywide Administrative Services...             None
# 2                      Department of Buildings (DOB)             None
# 3                Taxi and Limousine Commission (TLC)             None
# 4                Taxi and Limousine Commission (TLC)             None
#
#   contact_email     type                 updatedAt  ...  \
# 0          None  dataset  2024-12-29T20:05:32.000Z  ...
# 1          None  dataset  2024-12-27T14:09:28.000Z  ...
# 2          None  dataset  2024-12-29T21:06:44.000Z  ...
# 3          None  dataset  2024-12-29T23:06:31.000Z  ...
# 4          None  dataset  2024-12-29T20:07:08.000Z  ...
#
#                                  columns_description  \
# 0  [Last Time Updated, Certification Date, Base N...
# 1  [A candidate’s last name as it appears on thei...
# 2  [Proposed Dwelling Units, Document Number, Num...
# 3  [This is the number linked to your application...
# 4  [Driver Name\n\n, Last Time Updated, Type of L...
#
#                                       columns_format download_count  \
# 0  [{'displayStyle': 'plain', 'align': 'left'}, {...         535601
# 1  [{'displayStyle': 'plain', 'align': 'left'}, {...          68870
# 2  [{'align': 'right'}, {'align': 'right'}, {'ali...          59754
# 3  [{'precisionStyle': 'standard', 'noCommas': 't...          39667
# 4  [{'displayStyle': 'plain', 'align': 'left'}, {...         421843
#
#   provenance lens_view_type lens_display_type locked blob_mime_type  \
# 0   official        tabular             table  False           None
# 1   official        tabular             table  False           None
# 2   official        tabular             table  False           None
# 3   official        tabular             table  False           None
# 4   official        tabular             table  False           None
#
#   hide_from_data_json          publication_date
# 0               False  2021-04-05T13:20:47.000Z
# 1               False  2024-01-12T16:15:05.000Z
# 2               False  2020-06-22T18:23:35.000Z
# 3               False  2019-12-17T18:44:57.000Z
# 4               False  2024-01-11T19:58:17.000Z
#
# [5 rows x 27 columns]

# %%
# sort df by download count ascending order
df = (
    df
    .sort_values(by='download_count')
    .reset_index(drop=True)
)

# sanity check
print(df.shape)
df.head()
# Out:
# (2559, 27)
#                                                 name         id resource_name  \
# 0                   Legal Defense Trust Expenditures  mhyv-6iza          None
# 1                      Legal Defense Trust Donations  jsiv-zh9r          None
# 2             Legal Defense Trust Refunded Donations  t3pj-3dgu          None
# 3  Summer Sports Experience and "Kids in Motion" ...  4pta-f4ca          None
# 4              Aquatics Programming: 2021 to current  bzby-7sfr          None
#
#   parent_fxf                                        description  \
# 0         []  Pursuant to the City's Legal Defense Trusts La...
# 1         []  Pursuant to the City's Legal Defense Trusts La...
# 2         []  Pursuant to the City's Legal Defense Trusts La...
# 3         []  The Kids in Motion (KIM) program provides free...
# 4         []  This dataset contains attendance and location ...
#
#                           attribution  \
# 0  Conflicts of Interest Board (COIB)
# 1  Conflicts of Interest Board (COIB)
# 2  Conflicts of Interest Board (COIB)
# 3                                None
# 4                                None
#
#                                     attribution_link contact_email     type  \
# 0               https://coib-ldt.cityofnewyork.us/s/          None  dataset
# 1               https://coib-ldt.cityofnewyork.us/s/          None  dataset
# 2  https://www.nyc.gov/site/coib/public-documents...          None  dataset
# 3                                               None          None  dataset
# 4                                               None          None  dataset
#
#                   updatedAt  ...  \
# 0  2024-12-23T17:41:28.000Z  ...
# 1  2024-12-23T17:38:51.000Z  ...
# 2  2024-12-23T17:40:52.000Z  ...
# 3  2024-12-28T14:01:41.000Z  ...
# 4  2024-12-27T15:50:15.000Z  ...
#
#                                  columns_description  \
# 0  [Amount of the expenditure, Date the expenses ...
# 1  [Donor's state, Donor's city, Value of the don...
# 2  [The name of the legal defense trust refunding...
# 3  [Name of sport played for Summer Sports Experi...
# 4  [Location of the swim class, Session during wh...
#
#                                       columns_format download_count  \
# 0  [{'precisionStyle': 'currency', 'decimalSepara...             13
# 1  [{}, {}, {'precision': '2', 'decimalSeparator'...             14
# 2  [{}, {'precisionStyle': 'currency', 'decimalSe...             14
# 3  [{}, {}, {}, {}, {}, {}, {'decimalSeparator': ...             15
# 4  [{}, {}, {}, {}, {}, {}, {'decimalSeparator': ...             16
#
#   provenance lens_view_type lens_display_type locked blob_mime_type  \
# 0   official        tabular             table  False           None
# 1   official        tabular             table  False           None
# 2   official        tabular             table  False           None
# 3   official        tabular             table  False           None
# 4   official        tabular             table  False           None
#
#   hide_from_data_json          publication_date
# 0               False  2024-09-18T19:58:13.000Z
# 1               False  2024-09-18T19:15:13.000Z
# 2               False  2024-09-18T19:37:40.000Z
# 3               False  2024-11-25T16:05:22.000Z
# 4               False  2024-11-26T19:38:05.000Z
#
# [5 rows x 27 columns]

# %%
df = df.loc[:, ['id']]

# sanity check
print(df.shape)
df.head()
# Out:
# (2559, 1)
#           id
# 0  mhyv-6iza
# 1  jsiv-zh9r
# 2  t3pj-3dgu
# 3  4pta-f4ca
# 4  bzby-7sfr

# %%
# save as a CSV file
df.to_csv('../data/dataset-ids.csv', index=False)

# %%
# sanity check
# %ls ../data/
# Out:
# columns-large-datasets.csv  dataset-ids.csv
# columns.csv                 datasets.csv
